# %%
import os
import pandas as pd
import pyarrow.parquet as pq

def merge_parquet_files(input_folder, output_file):
    # 입력 폴더 내의 모든 parquet 파일 목록 가져오기
    parquet_files = [os.path.join(input_folder, f) for f in os.listdir(input_folder) if f.endswith('.parquet')]
    
    # 모든 parquet 파일 읽어서 데이터프레임 리스트에 저장
    dataframes = []
    for file in parquet_files:
        df = pd.read_parquet(file)
        dataframes.append(df)
    
    # 데이터프레임 병합
    merged_df = pd.concat(dataframes, ignore_index=True)
    
    # 병합된 데이터프레임을 parquet 파일로 저장
    merged_df.to_parquet(output_file)
    print(f"Merged {len(parquet_files)} files into {output_file}")

# 예시 사용법
input_folder = 'parquets'
output_file = 'T5_results.parquet'
merge_parquet_files(input_folder, output_file)

# %%
target = r'C:\Users\wjdrb\vscode_code\MathBridge_new\data\until_gpt_not_len_5_cleaned_unique_eq.parquet'
df = pd.read_parquet(target)
df

# %%
T5 = pd.read_parquet('T5_results.parquet')

# %%
input = pd.read_parquet('T5_allocate.parquet')

# %%
input

# %%
dataset = pd.read_parquet('T5_allocate.parquet',engine="fastparquet")

# %%
dataset

# %%
import pandas as pd
import os
import glob

def get_start_index(batch_num, part_num, batch_size, prev_parts_counts):
    # 이전 파트들의 개수를 합산하여 시작 인덱스 계산
    start_index = batch_num * batch_size + sum(prev_parts_counts[:part_num])
    return start_index

def load_and_process_file(filename, dataset, batch_size, prev_parts_counts):
    # 파일 로드
    df_spoken = pd.read_parquet(filename, engine='fastparquet')
    
    # 파일명에서 배치 번호와 파트 번호 추출
    batch_num = int(filename.split('batch')[1].split('_')[0])
    part_num = int(filename.split('part')[1].split('.')[0])
    
    # 시작 인덱스 계산
    start_idx = get_start_index(batch_num, part_num, batch_size, prev_parts_counts[batch_num])
    
    # `equation` 데이터 추가
    df_spoken['equation'] = dataset['equation'].iloc[start_idx:start_idx + len(df_spoken)].reset_index(drop=True)
    
    # 결과 반환
    return df_spoken

def main(dataset):
    # 모든 parquet 파일을 찾아 처리
    files = glob.glob('parquets/*.parquet')
    num_models = 25  # 모델 수
    num_samples = len(dataset)
    batch_size = num_samples // num_models
    
    # 각 배치의 파트 수 저장 (파트 수는 파일 수에서 추론)
    prev_parts_counts = [[] for _ in range(num_models)]
    for file in files:
        batch_num = int(file.split('batch')[1].split('_')[0])
        part_num = int(file.split('part')[1].split('.')[0])
        if len(prev_parts_counts[batch_num]) <= part_num:
            prev_parts_counts[batch_num].extend([0] * (part_num + 1 - len(prev_parts_counts[batch_num])))
        prev_parts_counts[batch_num][part_num] = pd.read_parquet(file, engine='fastparquet').shape[0]
    
    results = [load_and_process_file(file, dataset, batch_size, prev_parts_counts) for file in files]
    
    # 모든 결과를 하나의 데이터프레임으로 합치기
    final_result = pd.concat(results, ignore_index=True)
    return final_result

# 가정: dataset이 이미 로드되어 있음
final_df = main(dataset)
print(final_df.head())

# %%
final_df

# %%
target = r'C:\Users\wjdrb\vscode_code\MathBridge_new\data\until_gpt_not_len_5_cleaned_unique_eq.parquet'
df = pd.read_parquet(target, engine='fastparquet')
df
# Out:
#                                              context_before  \
# 0         The horizontal axis represents the exponent range
# 1                                                      Here
# 2                                      The agent 's actions
# 3         are modeled by a stochastic control process wi...
# 4                                                      Here
# ...                                                     ...
# 12052503  The coordinates of a projected demeaned data p...
# 12052504                               Let 's now study the
# 12052505                                 fitting the points
# 12052506                                       Suppose that
# 12052507                                            What is
#
#                                                    equation  \
# 0                                         $ \in [ 3 , 7 ] $
# 1                                                 $ d\eta $
# 2                                               $ a ( t ) $
# 3                                            $ \sigma^2_t $
# 4                                               $ \deltat $
# ...                                                     ...
# 12052503  $ \Gamma_ { k } =\Sigma_ { k } V_ { k } ^ { T } $
# 12052504                                     $ 48^ { th } $
# 12052505  $ $ ( 0,1 ) , ( 1,0 ) , ( 2,1.5 ) , ( 3,4 ) , ...
# 12052506  $ \mathbf { u } =\left [ \begin { array } { c ...
# 12052507  $ \operatorname { rank } ( \mathbf { u } \ \ma...
#
#                                               context_after  eq_type  \
# 0         . We selected those categorical colors from Co...        0
# 1         denotes the system noise , modeled as a Wiener...        0
# 2         are modeled by a stochastic control process wi...        0
# 3         controlled by the agent and with a mean of zer...        0
# 4         denotes the physical time step , and we adopte...        0
# ...                                                     ...      ...
# 12052503                                                           0
# 12052504       case , which is represented by the column of        0
# 12052505                                                  1        1
# 12052506                                                and        0
# 12052507           and what is a basis for its column space        0
#
#                           paper_number paper_type  equation_len  \
# 0                           2301.00002  arxiv2023            17
# 1                           2301.00005  arxiv2023             9
# 2                           2301.00005  arxiv2023            11
# 3                           2301.00005  arxiv2023            14
# 4                           2301.00005  arxiv2023            11
# ...                                ...        ...           ...
# 12052503  Understanding Linear Algebra   textbook            49
# 12052504  Understanding Linear Algebra   textbook            14
# 12052505  Understanding Linear Algebra   textbook            59
# 12052506  Understanding Linear Algebra   textbook            79
# 12052507  Understanding Linear Algebra   textbook            68
#
#                                 spoken_English
# 0         Belongs to the interval from 3 to 7.
# 1                                       d eta.
# 2                              a function of t
# 3                         sigma squared sub t.
# 4                                     delta t.
# ...                                        ...
# 12052503                                  None
# 12052504                                  None
# 12052505                                  None
# 12052506                                  None
# 12052507                                  None
#
# [12052508 rows x 8 columns]

# %%
df['spoken_English'].isna().sum()
# Out:
# 11142308

# %%
final_df
# Out:
#                                             spoken_English  \
# 0                                               succ zero.
# 1                                        comma j in J plus
# 2                                 Minus one times X sub d.
# 3                                       comma j in J minus
# 4        Open parenthesis, one box plus negative one, c...
# ...                                                    ...
# 2216395  P times the derivative of Phi sub 1 times Max ...
# 2216396  P WORd equals QWord C multiplied by Witness of...
# 2216397  P a r P open parenthesis i d close parenthesis...
# 2216398  P a r P open parenthesis i d close parenthesis...
# 2216399  P a r P open parenthesis i d close parenthesis...
#
#                                                   equation
# 0                                             $ \succ \0 $
# 1                              $ , \quad j \in J^+ \ , , $
# 2                                        $ -\1 \odot X_d $
# 3                              $ , \quad j \in J^- \ , , $
# 4                        $ ( \1 \boxplus -\1 ) \odot X_d $
# ...                                                    ...
# 2216395   $ \PWord \Max_1 \Max_2 = \PWord' \Max_1 \Max_2 $
# 2216396  $ \PWord ' = \QWord \Conc \Witness { u } { u }...
# 2216397        $ \Par { \P ( \Monoid ) , \CoveringRT_1 } $
# 2216398        $ \Par { \P ( \Monoid ) , \CoveringRT_2 } $
# 2216399        $ \Par { \P ( \Monoid ) , \CoveringRT_3 } $
#
# [2216400 rows x 2 columns]

# %%
# 'equation' 열을 기준으로 병합
merged_df = df.merge(final_df[['equation', 'spoken_English']], on='equation', suffixes=('', '_temp'), how='left')

# 'spoken_English' 열 업데이트
df['spoken_English'] = merged_df['spoken_English_temp'].combine_first(df['spoken_English'])

# %%
df['spoken_English'].isna().sum()
# Out:
# 8925908

# %%
df
# Out:
#                                              context_before  \
# 0         The horizontal axis represents the exponent range
# 1                                                      Here
# 2                                      The agent 's actions
# 3         are modeled by a stochastic control process wi...
# 4                                                      Here
# ...                                                     ...
# 12052503  The coordinates of a projected demeaned data p...
# 12052504                               Let 's now study the
# 12052505                                 fitting the points
# 12052506                                       Suppose that
# 12052507                                            What is
#
#                                                    equation  \
# 0                                         $ \in [ 3 , 7 ] $
# 1                                                 $ d\eta $
# 2                                               $ a ( t ) $
# 3                                            $ \sigma^2_t $
# 4                                               $ \deltat $
# ...                                                     ...
# 12052503  $ \Gamma_ { k } =\Sigma_ { k } V_ { k } ^ { T } $
# 12052504                                     $ 48^ { th } $
# 12052505  $ $ ( 0,1 ) , ( 1,0 ) , ( 2,1.5 ) , ( 3,4 ) , ...
# 12052506  $ \mathbf { u } =\left [ \begin { array } { c ...
# 12052507  $ \operatorname { rank } ( \mathbf { u } \ \ma...
#
#                                               context_after  eq_type  \
# 0         . We selected those categorical colors from Co...        0
# 1         denotes the system noise , modeled as a Wiener...        0
# 2         are modeled by a stochastic control process wi...        0
# 3         controlled by the agent and with a mean of zer...        0
# 4         denotes the physical time step , and we adopte...        0
# ...                                                     ...      ...
# 12052503                                                           0
# 12052504       case , which is represented by the column of        0
# 12052505                                                  1        1
# 12052506                                                and        0
# 12052507           and what is a basis for its column space        0
#
#                           paper_number paper_type  equation_len  \
# 0                           2301.00002  arxiv2023            17
# 1                           2301.00005  arxiv2023             9
# 2                           2301.00005  arxiv2023            11
# 3                           2301.00005  arxiv2023            14
# 4                           2301.00005  arxiv2023            11
# ...                                ...        ...           ...
# 12052503  Understanding Linear Algebra   textbook            49
# 12052504  Understanding Linear Algebra   textbook            14
# 12052505  Understanding Linear Algebra   textbook            59
# 12052506  Understanding Linear Algebra   textbook            79
# 12052507  Understanding Linear Algebra   textbook            68
#
#                                 spoken_English
# 0         Belongs to the interval from 3 to 7.
# 1                                       d eta.
# 2                              a function of t
# 3                         sigma squared sub t.
# 4                                     delta t.
# ...                                        ...
# 12052503                                  None
# 12052504                                  None
# 12052505                                  None
# 12052506                                  None
# 12052507                                  None
#
# [12052508 rows x 8 columns]

# %%
df_filtered = df.filter(['equation', 'spoken_English'])
df_filtered
# Out:
#                                                    equation  \
# 0                                         $ \in [ 3 , 7 ] $
# 1                                                 $ d\eta $
# 2                                               $ a ( t ) $
# 3                                            $ \sigma^2_t $
# 4                                               $ \deltat $
# ...                                                     ...
# 12052503  $ \Gamma_ { k } =\Sigma_ { k } V_ { k } ^ { T } $
# 12052504                                     $ 48^ { th } $
# 12052505  $ $ ( 0,1 ) , ( 1,0 ) , ( 2,1.5 ) , ( 3,4 ) , ...
# 12052506  $ \mathbf { u } =\left [ \begin { array } { c ...
# 12052507  $ \operatorname { rank } ( \mathbf { u } \ \ma...
#
#                                 spoken_English
# 0         Belongs to the interval from 3 to 7.
# 1                                       d eta.
# 2                              a function of t
# 3                         sigma squared sub t.
# 4                                     delta t.
# ...                                        ...
# 12052503                                  None
# 12052504                                  None
# 12052505                                  None
# 12052506                                  None
# 12052507                                  None
#
# [12052508 rows x 2 columns]

# %%
target = r'C:\Users\wjdrb\vscode_code\MathBridge_new\data\df_not_len_5_cleaned.parquet'
df_origin_without_5 = pd.read_parquet(target, engine='fastparquet')
df_origin_without_5
# Out:
#                                              context_before  \
# 0         The horizontal axis represents the exponent range
# 1                                                      Here
# 2                                      The agent 's actions
# 3         are modeled by a stochastic control process wi...
# 4                                                      Here
# ...                                                     ...
# 33014810                              What does the product
# 33014811                             gives matrices so that
# 33014812                                                The
# 33014813
# 33014814                                                179
#
#                         equation  \
# 0              $ \in [ 3 , 7 ] $
# 1                      $ d\eta $
# 2                    $ a ( t ) $
# 3                 $ \sigma^2_t $
# 4                    $ \deltat $
# ...                          ...
# 33014810      $ A\mathbf { v } $
# 33014811               $ PA=LU $
# 33014812                  $ QR $
# 33014813                 $ RGB $
# 33014814  $ YC_ { b } C_ { r } $
#
#                                               context_after  eq_type  \
# 0         . We selected those categorical colors from Co...        0
# 1         denotes the system noise , modeled as a Wiener...        0
# 2         are modeled by a stochastic control process wi...        0
# 3         controlled by the agent and with a mean of zer...        0
# 4         denotes the physical time step , and we adopte...        0
# ...                                                     ...      ...
# 33014810  represent ? Use the following cell to evaluate...        0
# 33014811                                                           0
# 33014812                            factorization of A is A        0
# 33014813                                  color model , 179        0
# 33014814  color model , 179 augmented matrix , 15 back s...        0
#
#                           paper_number paper_type  equation_len
# 0                           2301.00002  arxiv2023            17
# 1                           2301.00005  arxiv2023             9
# 2                           2301.00005  arxiv2023            11
# 3                           2301.00005  arxiv2023            14
# 4                           2301.00005  arxiv2023            11
# ...                                ...        ...           ...
# 33014810  Understanding Linear Algebra   textbook            18
# 33014811  Understanding Linear Algebra   textbook             9
# 33014812  Understanding Linear Algebra   textbook             6
# 33014813  Understanding Linear Algebra   textbook             7
# 33014814  Understanding Linear Algebra   textbook            22
#
# [33014815 rows x 7 columns]

# %%
df_merged_without_5 = pd.merge(df_origin_without_5, df_filtered, on='equation', how='left')
df_merged_without_5
# Out:
#                                              context_before  \
# 0         The horizontal axis represents the exponent range
# 1                                                      Here
# 2                                      The agent 's actions
# 3         are modeled by a stochastic control process wi...
# 4                                                      Here
# ...                                                     ...
# 33014810                              What does the product
# 33014811                             gives matrices so that
# 33014812                                                The
# 33014813
# 33014814                                                179
#
#                         equation  \
# 0              $ \in [ 3 , 7 ] $
# 1                      $ d\eta $
# 2                    $ a ( t ) $
# 3                 $ \sigma^2_t $
# 4                    $ \deltat $
# ...                          ...
# 33014810      $ A\mathbf { v } $
# 33014811               $ PA=LU $
# 33014812                  $ QR $
# 33014813                 $ RGB $
# 33014814  $ YC_ { b } C_ { r } $
#
#                                               context_after  eq_type  \
# 0         . We selected those categorical colors from Co...        0
# 1         denotes the system noise , modeled as a Wiener...        0
# 2         are modeled by a stochastic control process wi...        0
# 3         controlled by the agent and with a mean of zer...        0
# 4         denotes the physical time step , and we adopte...        0
# ...                                                     ...      ...
# 33014810  represent ? Use the following cell to evaluate...        0
# 33014811                                                           0
# 33014812                            factorization of A is A        0
# 33014813                                  color model , 179        0
# 33014814  color model , 179 augmented matrix , 15 back s...        0
#
#                           paper_number paper_type  equation_len  \
# 0                           2301.00002  arxiv2023            17
# 1                           2301.00005  arxiv2023             9
# 2                           2301.00005  arxiv2023            11
# 3                           2301.00005  arxiv2023            14
# 4                           2301.00005  arxiv2023            11
# ...                                ...        ...           ...
# 33014810  Understanding Linear Algebra   textbook            18
# 33014811  Understanding Linear Algebra   textbook             9
# 33014812  Understanding Linear Algebra   textbook             6
# 33014813  Understanding Linear Algebra   textbook             7
# 33014814  Understanding Linear Algebra   textbook            22
#
#                                 spoken_English
# 0         Belongs to the interval from 3 to 7.
# 1                                       d eta.
# 2                              a function of t
# 3                         sigma squared sub t.
# 4                                     delta t.
# ...                                        ...
# 33014810                                  None
# 33014811                 P A equals L times U.
# 33014812                                    QR
# 33014813                             RGB: None
# 33014814                                  None
#
# [33014815 rows x 8 columns]

# %%
target = r'C:\Users\wjdrb\vscode_code\MathBridge_new\data\df_len_5.parquet'
df_5 = pd.read_parquet(target, engine='fastparquet')
df_5
# Out:
#                                              context_before equation  \
# 1         Figures on the top row are magnified views of ...    $ 1 $
# 2                           and the bottom row shows region    $ 2 $
# 4         Experiment II : examples of selected exponent ...    $ 3 $
# 5                                                              $ 5 $
# 6                                                       and    $ 7 $
# ...                                                     ...      ...
# 48780808               T `` ` * Find the singular values of    $ A $
# 48780809  * For what fraction of the variance do the fir...    $ A $
# 48780811                                             matrix    $ B $
# 48780814  Evaluating the following cell will load the vo...    $ A $
# 48780819                                                 If    $ A $
#
#                                               context_after  eq_type  \
# 1         , marked by orange-box on the left image , and...        0
# 2         . With white background , the white cylinders ...        0
# 4                                                         ,        0
# 5                                                     , and        0
# 6         ( from the second left to right ) . We could s...        0
# ...                                                     ...      ...
# 48780808  and use them to determine the variance in the ...        0
# 48780809                                  and construct the        0
# 48780811  whose entries are the coordinates of the demea...        0
# 48780814                                                           0
# 48780819                             can be diagonalized as        0
#
#                           paper_number paper_type  equation_len spoken_English
# 1                           2301.00002  arxiv2023             5            one
# 2                           2301.00002  arxiv2023             5            two
# 4                           2301.00002  arxiv2023             5          three
# 5                           2301.00002  arxiv2023             5           five
# 6                           2301.00002  arxiv2023             5          seven
# ...                                ...        ...           ...            ...
# 48780808  Understanding Linear Algebra   textbook             5              A
# 48780809  Understanding Linear Algebra   textbook             5              A
# 48780811  Understanding Linear Algebra   textbook             5              B
# 48780814  Understanding Linear Algebra   textbook             5              A
# 48780819  Understanding Linear Algebra   textbook             5              A
#
# [7112204 rows x 8 columns]

# %%
df_combined = pd.concat([df_merged_without_5, df_5], ignore_index=True)
df_combined
# Out:
#                                              context_before  \
# 0         The horizontal axis represents the exponent range
# 1                                                      Here
# 2                                      The agent 's actions
# 3         are modeled by a stochastic control process wi...
# 4                                                      Here
# ...                                                     ...
# 40127014               T `` ` * Find the singular values of
# 40127015  * For what fraction of the variance do the fir...
# 40127016                                             matrix
# 40127017  Evaluating the following cell will load the vo...
# 40127018                                                 If
#
#                    equation  \
# 0         $ \in [ 3 , 7 ] $
# 1                 $ d\eta $
# 2               $ a ( t ) $
# 3            $ \sigma^2_t $
# 4               $ \deltat $
# ...                     ...
# 40127014              $ A $
# 40127015              $ A $
# 40127016              $ B $
# 40127017              $ A $
# 40127018              $ A $
#
#                                               context_after  eq_type  \
# 0         . We selected those categorical colors from Co...        0
# 1         denotes the system noise , modeled as a Wiener...        0
# 2         are modeled by a stochastic control process wi...        0
# 3         controlled by the agent and with a mean of zer...        0
# 4         denotes the physical time step , and we adopte...        0
# ...                                                     ...      ...
# 40127014  and use them to determine the variance in the ...        0
# 40127015                                  and construct the        0
# 40127016  whose entries are the coordinates of the demea...        0
# 40127017                                                           0
# 40127018                             can be diagonalized as        0
#
#                           paper_number paper_type  equation_len  \
# 0                           2301.00002  arxiv2023            17
# 1                           2301.00005  arxiv2023             9
# 2                           2301.00005  arxiv2023            11
# 3                           2301.00005  arxiv2023            14
# 4                           2301.00005  arxiv2023            11
# ...                                ...        ...           ...
# 40127014  Understanding Linear Algebra   textbook             5
# 40127015  Understanding Linear Algebra   textbook             5
# 40127016  Understanding Linear Algebra   textbook             5
# 40127017  Understanding Linear Algebra   textbook             5
# 40127018  Understanding Linear Algebra   textbook             5
#
#                                 spoken_English
# 0         Belongs to the interval from 3 to 7.
# 1                                       d eta.
# 2                              a function of t
# 3                         sigma squared sub t.
# 4                                     delta t.
# ...                                        ...
# 40127014                                     A
# 40127015                                     A
# 40127016                                     B
# 40127017                                     A
# 40127018                                     A
#
# [40127019 rows x 8 columns]

# %%
df_cleaned = df_combined[df_combined['spoken_English'].notna() & 
        (df_combined['spoken_English'] != 'None') & 
        (df_combined['spoken_English'] != 'None.')]

# %%
df_cleaned
# Out:
#                                              context_before  \
# 0         The horizontal axis represents the exponent range
# 1                                                      Here
# 2                                      The agent 's actions
# 3         are modeled by a stochastic control process wi...
# 4                                                      Here
# ...                                                     ...
# 40127014               T `` ` * Find the singular values of
# 40127015  * For what fraction of the variance do the fir...
# 40127016                                             matrix
# 40127017  Evaluating the following cell will load the vo...
# 40127018                                                 If
#
#                    equation  \
# 0         $ \in [ 3 , 7 ] $
# 1                 $ d\eta $
# 2               $ a ( t ) $
# 3            $ \sigma^2_t $
# 4               $ \deltat $
# ...                     ...
# 40127014              $ A $
# 40127015              $ A $
# 40127016              $ B $
# 40127017              $ A $
# 40127018              $ A $
#
#                                               context_after  eq_type  \
# 0         . We selected those categorical colors from Co...        0
# 1         denotes the system noise , modeled as a Wiener...        0
# 2         are modeled by a stochastic control process wi...        0
# 3         controlled by the agent and with a mean of zer...        0
# 4         denotes the physical time step , and we adopte...        0
# ...                                                     ...      ...
# 40127014  and use them to determine the variance in the ...        0
# 40127015                                  and construct the        0
# 40127016  whose entries are the coordinates of the demea...        0
# 40127017                                                           0
# 40127018                             can be diagonalized as        0
#
#                           paper_number paper_type  equation_len  \
# 0                           2301.00002  arxiv2023            17
# 1                           2301.00005  arxiv2023             9
# 2                           2301.00005  arxiv2023            11
# 3                           2301.00005  arxiv2023            14
# 4                           2301.00005  arxiv2023            11
# ...                                ...        ...           ...
# 40127014  Understanding Linear Algebra   textbook             5
# 40127015  Understanding Linear Algebra   textbook             5
# 40127016  Understanding Linear Algebra   textbook             5
# 40127017  Understanding Linear Algebra   textbook             5
# 40127018  Understanding Linear Algebra   textbook             5
#
#                                 spoken_English
# 0         Belongs to the interval from 3 to 7.
# 1                                       d eta.
# 2                              a function of t
# 3                         sigma squared sub t.
# 4                                     delta t.
# ...                                        ...
# 40127014                                     A
# 40127015                                     A
# 40127016                                     B
# 40127017                                     A
# 40127018                                     A
#
# [23392383 rows x 8 columns]

# %%
df_cleaned.to_parquet('MathBridge_ver1', engine='pyarrow')

# %% [markdown]
# ## 재시작

# %%
import pandas as pd
df_cleaned = pd.read_parquet('MathBridge_ver1', engine='fastparquet')

# %%
df_cleaned["paper_number"]
# Out:
# 0                             2301.00002
# 1                             2301.00005
# 2                             2301.00005
# 3                             2301.00005
# 4                             2301.00005
#                         ...
# 40127014    Understanding Linear Algebra
# 40127015    Understanding Linear Algebra
# 40127016    Understanding Linear Algebra
# 40127017    Understanding Linear Algebra
# 40127018    Understanding Linear Algebra
# Name: paper_number, Length: 23392383, dtype: object

# %%
df_cleaned['arxiv_number'] = df_cleaned['paper_number'].str.extract('(\d+\.\d+)')
df_cleaned['textbook_title'] = df_cleaned['paper_number'].str.extract('([^\d.]+)')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\wjdrb\AppData\Local\Temp\ipykernel_87992\351531847.py:1: SyntaxWarning: invalid escape sequence '\d'
#   df_cleaned['arxiv_number'] = df_cleaned['paper_number'].str.extract('(\d+\.\d+)')
# C:\Users\wjdrb\AppData\Local\Temp\ipykernel_87992\351531847.py:2: SyntaxWarning: invalid escape sequence '\d'
#   df_cleaned['textbook_title'] = df_cleaned['paper_number'].str.extract('([^\d.]+)')

# %%
df_cleaned
# Out:
#                                              context_before  \
# 0         The horizontal axis represents the exponent range
# 1                                                      Here
# 2                                      The agent 's actions
# 3         are modeled by a stochastic control process wi...
# 4                                                      Here
# ...                                                     ...
# 40127014               T `` ` * Find the singular values of
# 40127015  * For what fraction of the variance do the fir...
# 40127016                                             matrix
# 40127017  Evaluating the following cell will load the vo...
# 40127018                                                 If
#
#                    equation  \
# 0         $ \in [ 3 , 7 ] $
# 1                 $ d\eta $
# 2               $ a ( t ) $
# 3            $ \sigma^2_t $
# 4               $ \deltat $
# ...                     ...
# 40127014              $ A $
# 40127015              $ A $
# 40127016              $ B $
# 40127017              $ A $
# 40127018              $ A $
#
#                                               context_after  eq_type  \
# 0         . We selected those categorical colors from Co...        0
# 1         denotes the system noise , modeled as a Wiener...        0
# 2         are modeled by a stochastic control process wi...        0
# 3         controlled by the agent and with a mean of zer...        0
# 4         denotes the physical time step , and we adopte...        0
# ...                                                     ...      ...
# 40127014  and use them to determine the variance in the ...        0
# 40127015                                  and construct the        0
# 40127016  whose entries are the coordinates of the demea...        0
# 40127017                                                           0
# 40127018                             can be diagonalized as        0
#
#                           paper_number paper_type  equation_len  \
# 0                           2301.00002  arxiv2023            17
# 1                           2301.00005  arxiv2023             9
# 2                           2301.00005  arxiv2023            11
# 3                           2301.00005  arxiv2023            14
# 4                           2301.00005  arxiv2023            11
# ...                                ...        ...           ...
# 40127014  Understanding Linear Algebra   textbook             5
# 40127015  Understanding Linear Algebra   textbook             5
# 40127016  Understanding Linear Algebra   textbook             5
# 40127017  Understanding Linear Algebra   textbook             5
# 40127018  Understanding Linear Algebra   textbook             5
#
#                                 spoken_English arxiv_number  \
# 0         Belongs to the interval from 3 to 7.   2301.00002
# 1                                       d eta.   2301.00005
# 2                              a function of t   2301.00005
# 3                         sigma squared sub t.   2301.00005
# 4                                     delta t.   2301.00005
# ...                                        ...          ...
# 40127014                                     A          NaN
# 40127015                                     A          NaN
# 40127016                                     B          NaN
# 40127017                                     A          NaN
# 40127018                                     A          NaN
#
#                         textbook_title
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# ...                                ...
# 40127014  Understanding Linear Algebra
# 40127015  Understanding Linear Algebra
# 40127016  Understanding Linear Algebra
# 40127017  Understanding Linear Algebra
# 40127018  Understanding Linear Algebra
#
# [23392383 rows x 10 columns]

# %%
df_cleaned = df_cleaned.drop('paper_number', axis=1)

# %%
df_cleaned
# Out:
#                                              context_before  \
# 0         The horizontal axis represents the exponent range
# 1                                                      Here
# 2                                      The agent 's actions
# 3         are modeled by a stochastic control process wi...
# 4                                                      Here
# ...                                                     ...
# 40127014               T `` ` * Find the singular values of
# 40127015  * For what fraction of the variance do the fir...
# 40127016                                             matrix
# 40127017  Evaluating the following cell will load the vo...
# 40127018                                                 If
#
#                    equation  \
# 0         $ \in [ 3 , 7 ] $
# 1                 $ d\eta $
# 2               $ a ( t ) $
# 3            $ \sigma^2_t $
# 4               $ \deltat $
# ...                     ...
# 40127014              $ A $
# 40127015              $ A $
# 40127016              $ B $
# 40127017              $ A $
# 40127018              $ A $
#
#                                               context_after  eq_type  \
# 0         . We selected those categorical colors from Co...        0
# 1         denotes the system noise , modeled as a Wiener...        0
# 2         are modeled by a stochastic control process wi...        0
# 3         controlled by the agent and with a mean of zer...        0
# 4         denotes the physical time step , and we adopte...        0
# ...                                                     ...      ...
# 40127014  and use them to determine the variance in the ...        0
# 40127015                                  and construct the        0
# 40127016  whose entries are the coordinates of the demea...        0
# 40127017                                                           0
# 40127018                             can be diagonalized as        0
#
#          paper_type  equation_len                        spoken_English  \
# 0         arxiv2023            17  Belongs to the interval from 3 to 7.
# 1         arxiv2023             9                                d eta.
# 2         arxiv2023            11                       a function of t
# 3         arxiv2023            14                  sigma squared sub t.
# 4         arxiv2023            11                              delta t.
# ...             ...           ...                                   ...
# 40127014   textbook             5                                     A
# 40127015   textbook             5                                     A
# 40127016   textbook             5                                     B
# 40127017   textbook             5                                     A
# 40127018   textbook             5                                     A
#
#          arxiv_number                textbook_title
# 0          2301.00002                           NaN
# 1          2301.00005                           NaN
# 2          2301.00005                           NaN
# 3          2301.00005                           NaN
# 4          2301.00005                           NaN
# ...               ...                           ...
# 40127014          NaN  Understanding Linear Algebra
# 40127015          NaN  Understanding Linear Algebra
# 40127016          NaN  Understanding Linear Algebra
# 40127017          NaN  Understanding Linear Algebra
# 40127018          NaN  Understanding Linear Algebra
#
# [23392383 rows x 9 columns]

# %%
df_cleaned.to_parquet('MathBridge_ver2', engine='pyarrow')

# %%
# 'arxiv_number' 열에서 고유한 값만 추출
unique_arxiv_numbers = df_cleaned['arxiv_number'].drop_duplicates()

# 새 데이터프레임 생성
df_arxiv_number = pd.DataFrame(unique_arxiv_numbers)

# 데이터프레임 인덱스 재설정 (선택적)
df_arxiv_number.reset_index(drop=True, inplace=True)
df_arxiv_number
# Out:
#        arxiv_number
# 0        2301.00002
# 1        2301.00005
# 2        2301.00006
# 3        2301.00007
# 4        2301.00008
# ...             ...
# 141027   2312.17641
# 141028    2312.1766
# 141029   2312.17674
# 141030   2312.17712
# 141031    2312.1774
#
# [141032 rows x 1 columns]

# %% [markdown]
# ## 분야

# %%
import requests

def fetch_arxiv_category(arxiv_id):
    url = f'http://export.arxiv.org/api/query?id_list={arxiv_id}'
    response = requests.get(url)
    if response.status_code == 200:
        # API로부터 응답 받기
        data = response.text
        # 응답에서 분야 정보 추출하기
        start = data.find('<arxiv:primary_category')
        start = data.find('term="', start) + 6
        end = data.find('"', start)
        category = data[start:end]
        return category
    else:
        return "API 요청에 실패하였습니다."

# 예시 사용법
arxiv_id = "1707.01495"
category = fetch_arxiv_category(arxiv_id)
print(f'논문 분야: {category}')
# Out:
# 논문 분야: cs.LG

# %%
import pandas as pd
import requests

def fetch_arxiv_category(arxiv_id):
    url = f'http://export.arxiv.org/api/query?id_list={arxiv_id}'
    response = requests.get(url)
    if response.status_code == 200:
        # API로부터 응답 받기
        data = response.text
        # 응답에서 분야 정보 추출하기
        start = data.find('<arxiv:primary_category')
        start = data.find('term="', start) + 6
        end = data.find('"', start)
        category = data[start:end]
        print(category)
        return category
    else:
        return None  # API 요청 실패 시 None 반환


# 각 논문 번호에 대해 분야를 조회하고 새 열로 저장
df_arxiv_number['category'] = df_arxiv_number['arxiv_number'].apply(fetch_arxiv_category)
# Out:
# cs.HC
# cs.AI
# cs.HC
# cs.LG
# cs.LG
# cs.LG
# cs.NE
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[78], line 22
#      18         return None  # API 요청 실패 시 None 반환
#      21 # 각 논문 번호에 대해 분야를 조회하고 새 열로 저장
# ---> 22 df_arxiv_number['category'] = df_arxiv_number['arxiv_number'].apply(fetch_arxiv_category)
#
# File c:\Users\wjdrb\vscode_code\venv\Lib\site-packages\pandas\core\series.py:4915, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4780 def apply(
#    4781     self,
#    4782     func: AggFuncType,
#    (...)
#    4787     **kwargs,
#    4788 ) -> DataFrame | Series:
#    4789     """
#    4790     Invoke function on values of Series.
#    4791
#    (...)
#    4906     dtype: float64
#    4907     """
#    4908     return SeriesApply(
#    4909         self,
#    4910         func,
#    4911         convert_dtype=convert_dtype,
#    4912         by_row=by_row,
#    4913         args=args,
#    4914         kwargs=kwargs,
# -> 4915     ).apply()
#
# File c:\Users\wjdrb\vscode_code\venv\Lib\site-packages\pandas\core\apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File c:\Users\wjdrb\vscode_code\venv\Lib\site-packages\pandas\core\apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File c:\Users\wjdrb\vscode_code\venv\Lib\site-packages\pandas\core\base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File c:\Users\wjdrb\vscode_code\venv\Lib\site-packages\pandas\core\algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# Cell In[78], line 6, in fetch_arxiv_category(arxiv_id)
#       4 def fetch_arxiv_category(arxiv_id):
#       5     url = f'http://export.arxiv.org/api/query?id_list={arxiv_id}'
# ----> 6     response = requests.get(url)
#       7     if response.status_code == 200:
#       8         # API로부터 응답 받기
#       9         data = response.text
#
# File c:\Users\wjdrb\vscode_code\venv\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\Users\wjdrb\vscode_code\venv\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\wjdrb\vscode_code\venv\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\wjdrb\vscode_code\venv\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\wjdrb\vscode_code\venv\Lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File c:\Users\wjdrb\vscode_code\venv\Lib\site-packages\urllib3\connectionpool.py:793, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     790 response_conn = conn if not release_conn else None
#     792 # Make the request on the HTTPConnection object
# --> 793 response = self._make_request(
#     794     conn,
#     795     method,
#     796     url,
#     797     timeout=timeout_obj,
#     798     body=body,
#     799     headers=headers,
#     800     chunked=chunked,
#     801     retries=retries,
#     802     response_conn=response_conn,
#     803     preload_content=preload_content,
#     804     decode_content=decode_content,
#     805     **response_kw,
#     806 )
#     808 # Everything went great!
#     809 clean_exit = True
#
# File c:\Users\wjdrb\vscode_code\venv\Lib\site-packages\urllib3\connectionpool.py:496, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     493 # conn.request() calls http.client.*.request, not the method in
#     494 # urllib3.request. It also calls makefile (recv) on the socket.
#     495 try:
# --> 496     conn.request(
#     497         method,
#     498         url,
#     499         body=body,
#     500         headers=headers,
#     501         chunked=chunked,
#     502         preload_content=preload_content,
#     503         decode_content=decode_content,
#     504         enforce_content_length=enforce_content_length,
#     505     )
#     507 # We are swallowing BrokenPipeError (errno.EPIPE) since the server is
#     508 # legitimately able to close the connection after sending a valid response.
#     509 # With this behaviour, the received response is still readable.
#     510 except BrokenPipeError:
#
# File c:\Users\wjdrb\vscode_code\venv\Lib\site-packages\urllib3\connection.py:400, in HTTPConnection.request(self, method, url, body, headers, chunked, preload_content, decode_content, enforce_content_length)
#     398 for header, value in headers.items():
#     399     self.putheader(header, value)
# --> 400 self.endheaders()
#     402 # If we're given a body we start sending that in chunks.
#     403 if chunks is not None:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\http\client.py:1326, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1324 else:
#    1325     raise CannotSendHeader()
# -> 1326 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\http\client.py:1085, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1083 msg = b"\r\n".join(self._buffer)
#    1084 del self._buffer[:]
# -> 1085 self.send(msg)
#    1087 if message_body is not None:
#    1088
#    1089     # create a consistent interface to message_body
#    1090     if hasattr(message_body, 'read'):
#    1091         # Let file-like take precedence over byte-like.  This
#    1092         # is needed to allow the current position of mmap'ed
#    1093         # files to be taken into account.
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\http\client.py:1029, in HTTPConnection.send(self, data)
#    1027 if self.sock is None:
#    1028     if self.auto_open:
# -> 1029         self.connect()
#    1030     else:
#    1031         raise NotConnected()
#
# File c:\Users\wjdrb\vscode_code\venv\Lib\site-packages\urllib3\connection.py:238, in HTTPConnection.connect(self)
#     237 def connect(self) -> None:
# --> 238     self.sock = self._new_conn()
#     239     if self._tunnel_host:
#     240         # If we're tunneling it means we're connected to our proxy.
#     241         self._has_connected_to_proxy = True
#
# File c:\Users\wjdrb\vscode_code\venv\Lib\site-packages\urllib3\connection.py:198, in HTTPConnection._new_conn(self)
#     193 """Establish a socket connection and set nodelay settings on it.
#     194
#     195 :return: New socket connection.
#     196 """
#     197 try:
# --> 198     sock = connection.create_connection(
#     199         (self._dns_host, self.port),
#     200         self.timeout,
#     201         source_address=self.source_address,
#     202         socket_options=self.socket_options,
#     203     )
#     204 except socket.gaierror as e:
#     205     raise NameResolutionError(self.host, self, e) from e
#
# File c:\Users\wjdrb\vscode_code\venv\Lib\site-packages\urllib3\util\connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      71 if source_address:
#      72     sock.bind(source_address)
# ---> 73 sock.connect(sa)
#      74 # Break explicitly a reference cycle
#      75 err = None
#
# KeyboardInterrupt:

# %%
import pandas as pd
import requests
from concurrent.futures import ThreadPoolExecutor, as_completed

def fetch_arxiv_category(arxiv_id):
    url = f'http://export.arxiv.org/api/query?id_list={arxiv_id}'
    try:
        response = requests.get(url)
        response.raise_for_status()  # 응답 코드가 오류를 나타내면 예외 발생
        data = response.text
        start = data.find('<arxiv:primary_category')
        start = data.find('term="', start) + 6
        end = data.find('"', start)
        category = data[start:end]
        print(category)
        return category
    except requests.RequestException as e:
        print(f"Request failed for {arxiv_id}: {e}")
        return None

def fetch_categories(paper_ids):
    # 최대 스레드 수를 지정하여 ThreadPoolExecutor 생성
    with ThreadPoolExecutor(max_workers=20) as executor:
        # 각 paper_id에 대한 fetch_arxiv_category 함수 호출 스케줄링
        future_to_id = {executor.submit(fetch_arxiv_category, pid): pid for pid in paper_ids}
        # 완료되면 결과 수집
        for future in as_completed(future_to_id):
            arxiv_id = future_to_id[future]
            try:
                yield arxiv_id, future.result()
            except Exception as exc:
                print(f'{arxiv_id} generated an exception: {exc}')

# DataFrame에 있는 paper_number에 대해 분야를 조회
categories = {pid: cat for pid, cat in fetch_categories(df_arxiv_number['arxiv_number'])}

# DataFrame에 category 열 추가
df_arxiv_number['category'] = df_arxiv_number['arxiv_number'].map(categories)
df_arxiv_number
# Out:
# cs.HC
# cs.AI
# cs.LG
# cs.NE
# cs.LG
# cs.HC
# cs.LG
# physics.ed-ph
# cs.LG
# cs.LG
# gr-qc
# astro-ph.GA
# quant-ph
# astro-ph.HE
# cs.HC
# cond-mat.mes-hall
# cs.CV
# gr-qc
# astro-ph.HE
# hep-th
# physics.flu-dyn
# cs.LG
# math-ph
# cs.LG
# math.QA
# hep-lat
# hep-th
# stat.OT
# hep-ph
# quant-ph
# quant-ph
# cs.FL
# gr-qc
# quant-ph
# cs.SE
# stat.AP
# cs.NI
# cs.HC
# math.OC
# astro-ph.SR
# stat.ME
# cs.CL
# cs.CL
# cs.OS
# cs.CC
# math.NA
# cs.IT
# hep-ph
# physics.flu-dyn
# stat.AP
# math.PR
# hep-ph
# physics.soc-ph
# cond-mat.supr-con
# cs.LG
# math.OC
# stat.ML
# math.ATmath.GT
#
# cond-mat.quant-gas
# cond-mat.str-elcond-mat.mtrl-sci
#
# cond-mat.mes-hall
# cs.CR
# cs.LG
# math.ST
# math.CO
# cs.SI
# cs.LG
# astro-ph.HE
# cond-mat.mtrl-sci
# math.AP
# physics.app-ph
# quant-ph
# eess.IV
# cond-mat.str-el
# physics.ed-ph
# cond-mat.mtrl-sci
# math.CO
# cs.CC
# cond-mat.mtrl-sci
# quant-ph
# math.ST
# cs.HC
# cond-mat.mtrl-sci
# cs.LG
# astro-ph.SR
# cs.CV
# cs.CV
# q-bio.NC
# cs.CV
# physics.soc-ph
# cs.LG
# cs.CL
# math.AG
# cond-mat.stat-mech
# cs.IT
# physics.plasm-ph
# eess.SP
# math.AP
# cs.SI
# astro-ph.SR
# math.OC
# math.NA
# cond-mat.mtrl-sci
# cond-mat.soft
# cs.LG
# math.NA
# nucl-th
# cs.NE
# math.OC
# physics.flu-dyn
# math.DS
# math.CO
# math.AP
# quant-ph
# cs.RO
# Request failed for 2301.002: 400 Client Error: Bad Request for url: http://export.arxiv.org/api/query?id_list=2301.002
# cs.FL
# stat.ML
# nucl-th
# cond-mat.mes-hall
# astro-ph.GA
# math.AP
# math.SP
# hep-ph
# cond-mat.quant-gas
# hep-th
# physics.ins-det
# nucl-th
# astro-ph.HE
# astro-ph.GA
# cs.DL
# math.OC
# math.AP
# astro-ph.SR
# cs.CV
# hep-ph
# econ.TH
# hep-th
# hep-th
# math.OC
# cs.CV
# math.FA
# econ.TH
# astro-ph.HE
# physics.ed-ph
# eess.IV
# gr-qc
# stat.ML
# q-fin.CP
# math.AG
# math.DG
# econ.EM
# cs.CR
# quant-ph
# cs.MM
# hep-th
# quant-ph
# math.OC
# astro-ph.GA
# hep-th
# nucl-th
# cs.NI
# cs.CV
# math.CO
# nlin.CD
# math.PR
# cs.IT
# cond-mat.soft
# math.SG
# hep-ph
# econ.EM
# math.CO
# cs.LG
# cond-mat.str-el
# math.DG
# math.CO
# math.GT
# math-ph
# econ.EM
# astro-ph.EP
# hep-th
# stat.AP
# cs.LG
# math.GT
# math.CO
# math.CT
# cond-mat.stat-mech
# cs.CL
# cond-mat.mtrl-sci
# cs.CL
# eess.SP
# astro-ph.SR
# math.CO
# gr-qc
# cs.SC
# math.CO
# cs.DS
# cond-mat.mes-hall
# gr-qc
# cs.LG
# eess.SY
# math-ph
# stat.ME
# hep-ph
# cond-mat.other
# cond-mat.mtrl-sci
# math.OC
# math.AG
# cs.LG
# quant-ph
# cs.RO
# cs.LG
# hep-ph
# math.CO
# hep-lat
# hep-ph
# math.ST
# cs.CV
# eess.IV
# cs.LG
# astro-ph.CO
# physics.flu-dyn
# cs.SI
# cs.LG
# gr-qc
# cs.LG
# astro-ph.HE
# physics.atm-clus
# cs.LG
# eess.SP
# hep-th
# cs.RO
# math.HO
# cs.CV
# cs.CV
# econ.GN
# astro-ph.CO
# cs.CL
# math.ST
# physics.flu-dyn
# hep-th
# math.AG
# physics.optics
# cs.LG
# physics.ao-ph
# physics.flu-dyn
# cs.DS
# cs.CL
# cs.LG
# cs.LG
# cs.LG
# cond-mat.str-el
# cs.CV
# physics.bio-ph
# math.PR
# cs.CL
# Request failed for 2301.004: 400 Client Error: Bad Request for url: http://export.arxiv.org/api/query?id_list=2301.004
# math.RA
# math.CO
# cs.CV
# physics.soc-ph
# cs.CV
# hep-ph
# nlin.PS
# cs.CL
# cs.CV
# quant-ph
# math.OC
# math.OC
# physics.ao-ph
# quant-ph
# cs.CV
# cond-mat.quant-gas
# cs.LG
# cs.CL
# cs.CY
# cs.CV
# cs.LG
# cs.CR
# eess.SP
# math.NT
# cs.CV
# eess.AS
# gr-qc
# math.RT
# cs.RO
# cs.IT
# math.OC
# cs.CR
# cond-mat.mes-hall
# math.PR
# math.CA
# cs.LG
# stat.OT
# math.DS
# cond-mat.soft
# math.OC
# cs.FL
# cond-mat.str-el
# cond-mat.str-el
# math.OC
# math.GR
# math.PR
# quant-ph
# astro-ph.GA
# cs.IT
# cs.HC
# hep-ph
# cond-mat.quant-gas
# cs.RO
# cs.SE
# physics.ao-ph
# cs.LG
# math.ST
# cs.LG
# gr-qc
# astro-ph.HE
# Request failed for 2301.005: 400 Client Error: Bad Request for url: http://export.arxiv.org/api/query?id_list=2301.005
# physics.ins-det
# quant-ph
# cs.CL
# cs.HC
# math.AP
# econ.EM
# cs.SE
# cs.RO
# cs.LG
# cond-mat.mtrl-scihep-th
#
# cs.CV
# math.GR
# cs.RO
# cs.LG
# cs.IT
# math.DG
# quant-ph
# cs.CV
# nucl-th
# cond-mat.str-el
# cond-mat.mtrl-sci
# quant-ph
# physics.ao-ph
# nucl-th
# cs.LG
# cond-mat.mes-hall
# hep-th
# eess.IV
# quant-ph
# math.PR
# cs.CV
# stat.AP
# math.PR
# astro-ph.IM
# physics.ins-det
# cs.LG
# cs.IT
# cond-mat.stat-mech
# eess.SY
# quant-ph
# cs.SE
# astro-ph.HE
# math.OC
# quant-ph
# cond-mat.mes-hall
# astro-ph.HE
# cs.IT
# astro-ph.GA
# eess.SY
# stat.ME
# physics.chem-ph
# nucl-th
# cond-mat.stat-mech
# physics.app-ph
# cs.CV
# cs.IT
# cs.LG
# cs.NI
# cond-mat.mtrl-sci
# Request failed for 2301.006: 400 Client Error: Bad Request for url: http://export.arxiv.org/api/query?id_list=2301.006
# math.CT
# cond-mat.str-el
# cond-mat.mes-hall
# physics.flu-dyn
# astro-ph.SR
# math.OC
# gr-qc
# cs.CV
# cond-mat.mtrl-sci
# cs.SE
# gr-qc
# cs.CV
# math.NT
# cs.SI
# physics.atom-ph
# cs.AI
# math.PR
# cs.LG
# nucl-th
# cs.IT
# cond-mat.str-el
# cs.LG
# cs.GT
# hep-th
# gr-qc
# eess.SY
# math.HO
# q-bio.MN
# hep-ph
# q-fin.CP
# cs.IT
# eess.AS
# eess.AS
# cs.CL
# eess.AS
# hep-ph
# hep-th
# math.PR
# cond-mat.mtrl-sci
# physics.chem-ph
# stat.ME
# physics.chem-ph
# q-bio.PE
# quant-ph
# cs.LG
# astro-ph.EP
# gr-qc
# hep-th
# cond-mat.dis-nn
# math.NA
# hep-th
# gr-qc
# astro-ph.EP
# cs.CL
# cs.LG
# physics.hist-ph
# hep-ph
# gr-qc
# astro-ph.EP
# math.OC
# math-ph
# hep-th
# astro-ph.SR
# cs.IT
# cs.CL
# math.OC
# cs.CV
# math.DG
# cs.LG
# cs.LG
# stat.ME
# cs.OS
# cs.LG
# math.DS
# nucl-th
# cs.NE
# gr-qc
# cs.CV
# cs.MM
# hep-ph
# stat.ME
# cs.IT
# math.DS
# cs.CC
# astro-ph.SR
# quant-ph
# math.DG
# cs.LG
# cs.CC
# stat.ML
# quant-ph
# astro-ph.GA
# hep-ph
# cs.SC
# cs.CV
# physics.soc-ph
# astro-ph.GA
# math.AP
# cs.NI
# cs.DS
# cs.IT
# cond-mat.mtrl-sci
# cs.NI
# q-bio.NC
# math.NA
# hep-th
# cs.RO
# math.AP
# cs.CV
# eess.IV
# cs.IR
# cs.LG
# nlin.CD
# eess.SP
# physics.flu-dyn
# math.AP
# physics.soc-ph
# math.RT
# eess.IV
# eess.SY
# cond-mat.mtrl-sci
# physics.flu-dyn
# hep-ph
# math.NT
# cs.CL
# astro-ph.SR
# stat.ML
# hep-lat
# cs.DS
# cond-mat.mes-hall
# cs.IT
# Request failed for 2301.008: 400 Client Error: Bad Request for url: http://export.arxiv.org/api/query?id_list=2301.008
# stat.ML
# cs.LG
# math.NA
# cs.CV
# math.GT
# cs.CV
# hep-ph
# cond-mat.mes-hall
# cs.LG
# astro-ph.IM
# cs.LG
# cs.CL
# cs.LG
# math.DG
# hep-ph
# astro-ph.GA
# cond-mat.mes-hall
# astro-ph.GA
# hep-ph
# gr-qc
# astro-ph.GA
# cond-mat.str-el
# math.PR
# math.AG
# eess.AS
# astro-ph.HE
# cs.SE
# stat.ML
# math.DS
# eess.SP
# cs.IR
# math.AP
# math.DG
# math.CO
# cs.SI
# astro-ph.SR
# astro-ph.GA
# nucl-ex
# math.AP
# cs.LG
# eess.IV
# cs.LG
# hep-ex
# cond-mat.supr-con
# math.AG
# physics.class-ph
# math.NA
# cs.RO
# cs.CL
# cond-mat.stat-mech
# math.OC
# physics.atom-ph
# physics.plasm-ph
# hep-ph
# physics.app-ph
# eess.SY
# physics.ins-det
# math.RT
# math.NA
# math.ST
# math.AG
# cs.CL
# cs.RO
# physics.ao-ph
# cs.ET
# cs.LO
# cs.CV
# math.CO
# Request failed for 2301.009: 400 Client Error: Bad Request for url: http://export.arxiv.org/api/query?id_list=2301.009
# cs.RO
# math.NT
# astro-ph.SR
# cs.RO
# stat.ML
# cond-mat.soft
# econ.TH
# cs.NE
# quant-ph
# math.OC
# cs.LG
# gr-qc
# cond-mat.mes-hall
# math.PR
# math.AP
# stat.ML
# stat.ME
# cs.AI
# cs.NEcs.LG
#
# astro-ph.HE
# math.CO
# stat.ML
# cs.DB
# math.AT
# eess.SP
# eess.IV
# cs.RO
# astro-ph.GA
# cs.LG
# math.CO
# cs.IT
# cs.IT
# cs.LG
# cond-mat.mtrl-sci
# eess.SY
# eess.SP
# math.AP
# hep-th
# nucl-ex
# cs.CV
# cs.DC
# gr-qc
# cs.LG
# cond-mat.mtrl-sci
# physics.ins-det
# cs.CV
# math.AG
# cs.LG
# stat.ME
# physics.bio-ph
# math.AG
# cs.CL
# math.DG
# cs.CV
# cs.CV
# hep-ph
# math.NT
# eess.SP
# cs.IR
# cs.AI
# physics.optics
# cs.CV
# physics.plasm-ph
# cs.CV
# q-bio.PE
# physics.ins-det
# quant-ph
# quant-ph
# cs.CV
# Request failed for 2301.01: 400 Client Error: Bad Request for url: http://export.arxiv.org/api/query?id_list=2301.01
# astro-ph.SR
# hep-th
# cs.CV
# eess.IV
# cond-mat.mtrl-sci
# math.AP
# gr-qc
# math.DG
# physics.optics
# cs.LG
# cond-mat.mes-hall
# cond-mat.stat-mech
# math.AP
# astro-ph.CO
# physics.comp-ph
# astro-ph.HE
# cs.LG
# hep-ph
# cond-mat.str-el
# math.AG
# cs.CV
# math.CT
# math.FA
# cs.CV
# cs.LG
# cs.CR
# math.NA
# eess.SP
# cs.CR
# cs.LG
# physics.flu-dyn
# cs.LG
# cs.DC
# eess.SP
# math.ST
# math.MG
# math.DS
# quant-ph
# eess.IV
# cond-mat.mtrl-sci
# cs.CV
# physics.class-ph
# cs.CR
# math.RT
# cs.LG
# cond-mat.mtrl-sci
# math.AT
# quant-ph
# cs.CL
# astro-ph.EP
# math.NA
# cs.CL
# cs.DS
# eess.IV
# math.NT
# physics.app-ph
# math.AP
# math.AP
# hep-th
# math.ST
# physics.flu-dyn
# eess.IV
# cs.SI
# cs.CV
# astro-ph.SR
# cs.DS
# hep-ph
# cs.GR
# cs.LG
# cs.LG
# math.AP
# astro-ph.EP
# gr-qc
# math.AP
# cs.LG
# Request failed for 2301.011: 400 Client Error: Bad Request for url: http://export.arxiv.org/api/query?id_list=2301.011
# cond-mat.mes-hall
# q-bio.QM
# cs.LG
# eess.IV
# cs.LG
# quant-ph
# physics.optics
# cond-mat.stat-mech
# quant-ph
# cs.SE
# cs.RO
# cond-mat.supr-con
# cond-mat.mes-hall
# cs.CV
# cond-mat.soft
# cond-mat.mes-hall
# cond-mat.soft
# astro-ph.HE
# quant-ph
# cond-mat.mtrl-sci
# math.OC
# cond-mat.mtrl-sci
# eess.SY
# cs.CV
# cs.LG
# cs.CV
# cs.MS
# cs.CV
# math.AP
# astro-ph.GA
# math.CO
# math.PR
# math.AG
# cs.CV
# cs.SD
# gr-qc
# astro-ph.SR
# hep-ph
# eess.SY
# math-ph
# hep-th
# cs.CL
# physics.soc-ph
# eess.SP
# astro-ph.SR
# astro-ph.HE
# math.NA
# physics.app-ph
# eess.IV
# astro-ph.HE
# hep-ph
# gr-qc
# gr-qc
# quant-ph
# math.GM
# cs.DL
# math.AG
# cs.CR
# math.CT
# quant-ph
# cs.CV
# eess.SY
# physics.pop-ph
# math.NA
# math.QA
# cs.CV
# cs.CV
# physics.optics
# cs.CR
# cs.CR
# cs.CV
# cs.CR
# cs.IT
# math.CO
# hep-lat
# quant-ph
# cs.LG
# cs.RO
# stat.ML
# cs.RO
# eess.SY
# math.PR
# q-bio.NC
# stat.OT
# cs.NI
# physics.optics
# physics.ao-ph
# cs.SI
# cs.LO
# physics.atom-ph
# hep-th
# cs.LG
# astro-ph.EP
# q-bio.CB
# math.AG
# math.PR
# cs.CL
# eess.SY
# eess.IV
# cs.IT
# eess.SY
# physics.plasm-ph
# cs.CV
# cond-mat.stat-mech
# astro-ph.EP
# cs.LG
# math.ST
# astro-ph.GA
# physics.flu-dyn
# cond-mat.str-el
# astro-ph.IM
# math.DG
# nucl-th
# cs.CV
# cs.LG
# Request failed for 2301.013: 400 Client Error: Bad Request for url: http://export.arxiv.org/api/query?id_list=2301.013
# cond-mat.str-el
# astro-ph.GA
# hep-ph
# astro-ph.GA
# astro-ph.EP
# astro-ph.CO
# astro-ph.IM
# gr-qc
# astro-ph.SR
# hep-th
# astro-ph.HE
# physics.flu-dyn
# stat.ML
# math.AT
# astro-ph.HE
# cs.CG
# cs.RO
# cs.CR
# hep-th
# cs.GT
# cond-mat.stat-mech
# hep-th
# astro-ph.SR
# gr-qc
# cond-mat.mtrl-sci
# cs.LG
# math.CO
# astro-ph.GA
# physics.optics
# math.DS
# math.ST
# gr-qc
# physics.comp-ph
# math.NA
# cs.LG
# cond-mat.mtrl-sci
# math.RT
# cs.CV
# cond-mat.supr-con
# stat.ME
# cond-mat.mtrl-sci
# astro-ph.EP
# cs.LG
# cs.LG
# hep-th
# eess.IV
# eess.SY
# astro-ph.CO
# math.NT
# cs.CC
# eess.AS
# econ.EM
# astro-ph.CO
# gr-qc
# cond-mat.quant-gas
# cs.GT
# physics.ins-det
# eess.IV
# stat.ME
# stat.ME
# astro-ph.GA
# math.NT
# astro-ph.HE
# cs.AI
# stat.ME
# cs.SD
# cs.LG
# cond-mat.mes-hall
# quant-ph
# hep-lat
# astro-ph.HE
# astro-ph.GA
# cond-mat.mes-hall
# cs.LG
# physics.comp-ph
# math.CO
# cs.GR
# hep-th
# cs.MA
# math.NA
# cond-mat.quant-gas
# hep-ph
# cs.LG
# cs.CV
# stat.ME
# math.RT
# physics.data-an
# astro-ph.IM
# quant-ph
# astro-ph.HE
# cond-mat.mtrl-sci
# math.NA
# math.NA
# cond-mat.mtrl-sci
# math.DG
# cs.CV
# astro-ph.SR
# physics.plasm-ph
# math.NA
# astro-ph.SR
# cs.CV
# quant-ph
# cond-mat.str-el
# eess.SP
# q-bio.MN
# math.DS
# eess.IV
# cs.CV
# cs.LG
# cs.AR
# quant-ph
# quant-ph
# math.OC
# cs.CV
# astro-ph.GA
# eess.SY
# eess.SY
# cond-mat.soft
# physics.plasm-ph
# hep-ph
# math.PR
# hep-th
# cond-mat.supr-con
# eess.SP
# cond-mat.mes-hall
# cs.GR
# astro-ph.EP
# math.CO
# eess.SY
# cond-mat.mes-hall
# cs.SI
# stat.ME
# q-bio.NC
# physics.flu-dyn
# cs.CV
# physics.flu-dyn
# astro-ph.SR
# cs.NE
# astro-ph.CO
# cs.CV
# cs.IT
# cs.LG
# math.DS
# physics.plasm-ph
# Request failed for 2301.015: 400 Client Error: Bad Request for url: http://export.arxiv.org/api/query?id_list=2301.015
# cs.CV
# cs.CR
# astro-ph.CO
# hep-lat
# cond-mat.soft
# quant-ph
# cond-mat.str-el
# physics.soc-ph
# math.DS
# eess.SP
# cond-mat.mes-hall
# physics.ed-ph
# cs.CL
# physics.atom-ph
# hep-ph
# math.NA
# astro-ph.IM
# cond-mat.mtrl-sci
# cs.GT
# cond-mat.stat-mech
# astro-ph.SR
# physics.flu-dyn
# cond-mat.mtrl-sci
# cond-mat.mtrl-sci
# math.AP
# math.AG
# cond-mat.mtrl-sci
# cs.LG
# cond-mat.mtrl-sci
# physics.plasm-ph
# cs.DS
# cond-mat.soft
# cond-mat.stat-mech
# gr-qc
# physics.optics
# quant-ph
# hep-ex
# quant-ph
# gr-qc
# math.AP
# astro-ph.IM
# math.NA
# quant-ph
# math.AT
# cs.SE
# cs.LG
# cs.CV
# cs.DM
# cs.LG
# hep-ph
# cs.RO
# physics.flu-dyn
# cs.SD
# cs.CL
# eess.SY
# cond-mat.stat-mech
# cond-mat.mtrl-sciphysics.flu-dyn
#
# cs.NI
# q-bio.PE
# cs.CY
# quant-ph
# cs.LG
# cs.LG
# quant-ph
# math.GT
# eess.IV
# gr-qc
# physics.geo-ph
# cs.GT
# cs.AI
# astro-ph.HE
# cs.IT
# math.RT
# cs.CV
# stat.ME
# physics.plasm-ph
# cs.CY
# math.NT
# physics.flu-dyn
# cond-mat.mes-hall
# quant-ph
# cs.IT
# cond-mat.soft
# eess.SP
# cs.DS
# math.PR
# cs.CV
# math.PR
# physics.optics
# hep-ph
# math.QA
# physics.ins-det
# cond-mat.stat-mech
# astro-ph.SR
# astro-ph.SR
# cs.LG
# math.AP
# cond-mat.soft
# stat.ME
# math.NA
# math.AC
# cs.CL
# math.NA
# cs.CV
# physics.flu-dyn
# eess.SY
# stat.AP
# physics.flu-dyn
# physics.flu-dyn
# cond-mat.dis-nn
# eess.IV
# cs.CE
# astro-ph.EP
# math.AP
# hep-th
# hep-th
# physics.optics
# cs.SI
# physics.plasm-ph
# gr-qc
# stat.AP
# math.PR
# astro-ph.EP
# math.AG
# Request failed for 2301.017: 400 Client Error: Bad Request for url: http://export.arxiv.org/api/query?id_list=2301.017
# cs.CR
# cs.LG
# quant-ph
# cs.IT
# math.CO
# gr-qc
# cond-mat.dis-nn
# quant-ph
# hep-ph
# astro-ph.SR
# math.DS
# astro-ph.SR
# hep-th
# eess.SP
# physics.flu-dyn
# cs.LG
# cond-mat.mes-hall
# eess.IV
# q-bio.PE
# cond-mat.mtrl-sci
# eess.SP
# math.MG
# cs.IR
# hep-ph
# cs.GT
# cs.LG
# cs.GT
# hep-th
# cond-mat.mtrl-sci
# math.CO
# cs.CL
# math.NA
# math.NA
# hep-ph
# physics.app-ph
# cs.DC
# physics.app-ph
# astro-ph.SR
# cond-mat.dis-nn
# cs.CL
# math.ST
# cs.CV
# q-bio.GN
# cs.LG
# cs.LG
# physics.flu-dyn
# astro-ph.GA
# astro-ph.EP
# astro-ph.GA
# quant-ph
# astro-ph.IM
# cond-mat.soft
# astro-ph.HE
# quant-ph
# astro-ph.GA
# astro-ph.SR
# cond-mat.dis-nn
# astro-ph.EP
# hep-ph
# physics.plasm-ph
# eess.IV
# cs.CV
# physics.flu-dyn
# astro-ph.HE
# astro-ph.GA
# Request failed for 2301.018: 400 Client Error: Bad Request for url: http://export.arxiv.org/api/query?id_list=2301.018
# cs.LG
# astro-ph.HE
# hep-ph
# cs.LG
# cs.NE
# stat.ME
# astro-ph.SR
# cs.LG
# math.NA
# cs.CL
# cs.LG
# cs.AI
# math.SG
# cs.LG
# cond-mat.mtrl-sci
# cs.SI
# cs.RO
# cond-mat.mtrl-sci
# cs.LG
# math.NA
# cs.LG
# quant-ph
# cs.LG
# math.RT
# math.OC
# math.FA
# cond-mat.stat-mech
# cs.LG
# stat.ME
# gr-qc
# stat.ME
# cond-mat.stat-mech
# math.AG
# cond-mat.soft
# cs.SC
# math.FA
# cs.LG
# cond-mat.soft
# math.RT
# cs.LG
# physics.flu-dyn
# physics.ins-det
# cs.CV
# math.GT
# cs.CL
# cond-mat.str-el
# cs.CV
# nucl-th
# cs.LG
# cond-mat.supr-con
# cond-mat.mes-hall
# eess.SP
# cond-mat.mtrl-sci
# stat.ML
# quant-ph
# cs.AI
# cs.CR
# astro-ph.GA
# Request failed for 2301.019: 400 Client Error: Bad Request for url: http://export.arxiv.org/api/query?id_list=2301.019
# cs.NE
# cs.RO
# cond-mat.mes-hall
# cs.AI
# cs.IT
# cs.CV
# cs.MA
# physics.flu-dyn
# cs.CV
# cond-mat.mtrl-sci
# math.DS
# cs.DL
# physics.optics
# cs.CV
# math.CO
# cs.ET
# cs.CV
# math.GT
# cs.CL
# astro-ph.GA
# gr-qc
# physics.geo-ph
# astro-ph.HE
# astro-ph.SR
# astro-ph.HE
# cond-mat.mtrl-sci
# physics.bio-ph
# cs.LG
# cs.CL
# nucl-th
# cs.CV
# quant-ph
# cs.CV
# math.CO
# cs.CV
# astro-ph.GA
# astro-ph.HE
# quant-ph
# cond-mat.mes-hall
# math.ST
# math.PR
# cs.RO
# math.AP
# physics.optics
# math.NA
# math.NA
# cs.GR
# cs.DS
# cond-mat.mtrl-sci
# cs.RO
# cs.NE
# cs.CL
# cs.IT
# astro-ph.GA
# cs.FL
# cs.CY
# math.FA
# astro-ph.GA
# math.AP
# physics.flu-dyn
# cs.LG
# cs.CR
# hep-th
# astro-ph.GA
# quant-ph
# cond-mat.mtrl-sci
# nucl-th
# cs.CV
# stat.ML
# physics.flu-dyn
# eess.SP
# hep-ex
# math.PR
# nucl-th
# math.NA
# eess.SY
# eess.SY
# math.NA
# math.PR
# nlin.SI
# astro-ph.GA
# cs.CV
# math.NA
# eess.IV
# astro-ph.SR
# cond-mat.mtrl-sci
# math.DG
# math.RA
# math.SP
# math.GR
# eess.SP
# math.GT
# physics.flu-dyn
# physics.flu-dyn
# astro-ph.GA
# astro-ph.HE
# math.AP
# econ.EM
# cs.RO
# cs.DS
# math.NA
# quant-ph
# cs.IT
# cs.NI
# math.OC
# math.AT
# cs.HC
# cond-mat.stat-mech
# cs.LG
# eess.IV
# physics.comp-ph
# cs.CL
# physics.geo-ph
# cs.RO
# physics.optics
# math.NA
# physics.flu-dyn
# cs.AI
# math.OA
# astro-ph.SR
# math.GT
# math.GT
# math.NA
# quant-ph
# hep-th
# hep-ph
# math.AP
# hep-lat
# cond-mat.str-el
# math.ST
# cs.CR
# math.PR
# nucl-th
# math.NT
# math.AP
# physics.optics
# math.PR
# cs.CL
# cs.CL
# math.CO
# astro-ph.EP
# cond-mat.stat-mech
# math.NA
# nucl-th
# astro-ph.EP
# cond-mat.mes-hall
# cond-mat.stat-mech
# quant-ph
# cs.CV
# cs.GT
# nucl-thmath.NT
#
# cond-mat.mes-hall
# cond-mat.mtrl-sci
# cond-mat.str-el
# cs.LG
# cs.IT
# cs.CV
# quant-ph
# math.NA
# q-bio.QM
# physics.ins-det
# cs.LG
# math.AP
# cs.IT
# cond-mat.mes-hall
# astro-ph.EP
# quant-ph
# math.NA
# cs.LG
# cs.CC
# stat.ME
# physics.flu-dyn
# cond-mat.quant-gas
# quant-ph
# eess.IV
# cs.LG
# math.ST
# cond-mat.mes-hall
# math.PR
# physics.chem-ph
# nlin.AO
# hep-ex
# astro-ph.EP
# math.CO
# math.CO
# astro-ph.GA
# cond-mat.quant-gas
# eess.IV
# physics.plasm-ph
# cs.DB
# astro-ph.CO
# cs.CV
# physics.comp-ph
# quant-ph
# physics.app-ph
# q-bio.NC
# cond-mat.dis-nn
# math.OC
# cs.HC
# math.GR
# math.AC
# math.CO
# math.CO
# astro-ph.GA
# math.AT
# cs.LO
# eess.AS
# math.CV
# gr-qc
# cond-mat.soft
# hep-ex
# quant-ph
# math.NT
# math.NT
# stat.ML
# hep-ph
# quant-ph
# eess.IV
# cs.CV
# astro-ph.GA
# cs.CV
# math.OA
# math.DG
# cond-mat.quant-gas
# cs.CV
# cs.CV
# q-bio.GN
# cs.LG
# cond-mat.mes-hall
# hep-th
# math.CO
# astro-ph.GA
# astro-ph.CO
# astro-ph.GA
# cond-mat.supr-con
# astro-ph.GA
# cond-mat.mes-hall
# astro-ph.GA
# hep-ph
# hep-th
# math.AP
# astro-ph.HE
# eess.AS
# gr-qc
# hep-th
# astro-ph.GA
# math.LO
# gr-qc
# math.OC
# quant-ph
# hep-ex
# astro-ph.HE
# cs.CL
# cond-mat.str-el
# cond-mat.mtrl-sci
# math.NA
# cs.GT
# cond-mat.mtrl-sci
# Request failed for 2301.02288: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02289: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02291: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# math.AC
# q-bio.PE
# quant-ph
# Request failed for 2301.02292: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02294: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02296: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))Request failed for 2301.02298: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
#
# Request failed for 2301.02299: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02301: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02304: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02305: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.0231: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02309: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02312: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02315: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02316: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02313: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02318: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.0232: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02319: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02322: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02323: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02324: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02325: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02326: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02328: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02327: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02329: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02333: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02334: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02338: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.0234: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02342: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02345: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02346: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02348: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02349: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02351: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02353: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02352: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02354: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02355: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02356: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02358: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.0236: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02362: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02361: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02363: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02368: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02369: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.0237: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02372: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02371: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02376: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02382: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02379: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02378: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02383: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02384: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02385: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02387: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02388: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02392: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02393: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02394: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02395: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))Request failed for 2301.02396: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
#
# Request failed for 2301.02398: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02401: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02399: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02402: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02404: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02403: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02405: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02406: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02407: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02408: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02409: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02411: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02412: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02413: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02414: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02416: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02417: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02418: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02419: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.0242: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02421: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02423: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02422: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02424: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02428: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02429: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.0243: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02431: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02438: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02434: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02439: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02442: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02445: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02446: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02447: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02448: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02449: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.0245: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02452: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02451: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02453: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02455: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02454: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02456: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02457: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02459: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.0246: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02462: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02464: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02465: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02466: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02467: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02469: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.0247: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02471: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02472: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02475: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02481: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02482: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02484: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02485: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02486: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02487: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02489: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02493: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02494: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02495: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02498: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02499: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.025: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02502: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02503: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02504: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02507: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02505: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02509: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.0251: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02512: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02513: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02514: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02516: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02517: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02518: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02519: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02521: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02525: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02526: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02528: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02529: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02531: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02532: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02534: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02537: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.0254: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02539: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02541: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02548: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02549: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02553: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02554: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02555: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02557: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02558: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02559: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02561: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02563: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02564: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02572: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02567: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02568: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02573: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02574: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02577: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.0258: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02579: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02581: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02583: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02584: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02585: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02586: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02587: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02588: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02589: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.0259: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02591: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02592: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02593: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02594: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02595: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02601: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02602: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02603: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02604: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02605: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02606: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02608: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.0261: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02611: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02612: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02613: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02614: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02616: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02615: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02618: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02619: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02622: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02623: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02626: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02628: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02631: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02633: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02634: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02636: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02638: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02639: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02641: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02642: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02643: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02645: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02646: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02647: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02648: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02649: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02651: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02652: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02653: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02656: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02659: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02658: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02661: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02662: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02664: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02666: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02668: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.02669: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.0267: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# ...
# Request failed for 2301.03663: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03664: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03665: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03667: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03668: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03669: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.0367: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03672: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03673: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03676: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03677: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03678: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03681: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03679: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03684: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03685: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03686: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03689: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.0369: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03692: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03693: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03695: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03696: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03697: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03698: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03699: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.037: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03701: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03703: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03702: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03704: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03705: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03706: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03708: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03709: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.0371: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03711: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03712: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03713: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03714: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03715: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03717: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03721: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03718: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03722: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03723: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03725: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03727: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03729: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03728: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03731: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03733: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03736: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03738: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.0374: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03739: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03741: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03743: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03744: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03745: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03746: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03747: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.0375: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03749: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03751: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03752: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03753: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03755: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03757: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.0376: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03761: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03763: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03764: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03765: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03766: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03767: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03769: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.0377: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03773: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03775: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03776: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03777: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03778: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.0378: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03781: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03782: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03783: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03785: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03786: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03787: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03788: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.0379: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03793: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03792: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03795: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03796: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03798: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03801: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03802: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03803: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03805: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03806: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03808: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03809: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.0381: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03811: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03812: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03816: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03815: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03817: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03821: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03822: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03826: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03824: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03827: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03828: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03829: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03831: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Request failed for 2301.03833: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))

# %%
import requests
import feedparser
import pandas as pd
import time

def fetch_arxiv_metadata(start_index, max_results):
    base_url = 'http://export.arxiv.org/api/query?'
    year = 2023
    query = f'search_query=submittedDate:[{year}01010000+TO+{year}12312359]&sortBy=submittedDate&sortOrder=ascending'
    url = f'{base_url}{query}&start={start_index}&max_results={max_results}'
    
    response = requests.get(url)
    feed = feedparser.parse(response.content)
    
    papers = []
    for entry in feed.entries:
        paper_id = entry.id.split('/abs/')[-1]
        category = entry.arxiv_primary_category['term']
        papers.append({'id': paper_id, 'category': category})
    
    return papers

# 160,000개 데이터를 수집하기 위한 함수
def collect_all_papers(total_papers, max_per_request):
    all_papers = []
    for start in range(0, total_papers, max_per_request):
        print(f"Fetching papers {start + 1} to {start + max_per_request}...")
        current_papers = fetch_arxiv_metadata(start, max_per_request)
        all_papers.extend(current_papers)
        time.sleep(3)  # API 요청 사이에 약간의 지연을 두어 서버에 부하를 주지 않도록 합니다.
        if len(current_papers) < max_per_request:
            break  # 모든 데이터를 가져온 경우 루프를 종료합니다.
    
    return all_papers

# 데이터 수집 실행
total_required_papers = 160000
max_papers_per_request = 1600
papers_2023 = collect_all_papers(total_required_papers, max_papers_per_request)

# 데이터프레임으로 변환
papers_df = pd.DataFrame(papers_2023)
papers_df
# Out:
# Fetching papers 1 to 1600...
# Fetching papers 1601 to 3200...
#                 id     category
# 0     2301.00309v1      math.CO
# 1     2301.00310v2        cs.SI
# 2     2301.00311v2        gr-qc
# 3     2301.00312v2        cs.SI
# 4     2301.00313v2  astro-ph.SR
# ...            ...          ...
# 1595  2301.01936v1      math.PR
# 1596  2301.02631v3        gr-qc
# 1597  2301.01768v1        cs.CL
# 1598  2301.01937v1  astro-ph.GA
# 1599  2301.02565v1        gr-qc
#
# [1600 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
csfont = {'fontname':'Times New Roman'}

plt.rcParams['font.family'] = 'Times New Roman' # 예: 'serif', 'sans-serif', 'monospace' 등
plt.rcParams['font.serif'] = 'Times New Roman' # 특정 글꼴로 지정
plt.rcParams['font.size'] = 30  # 글꼴 크기를 12pt로 설정4
fontsize = plt.rcParams['font.size']





# 'category'에서 주 분야 추출
papers_df['primary_category'] = papers_df['category'].apply(lambda x: x.split('.')[0])

# 각 주 분야의 개수 계산
category_counts = papers_df['primary_category'].value_counts()

# 전체 논문 수 계산
total_papers = category_counts.sum()

# 3% 이하인 카테고리를 'etc'로 통합
threshold = 0.06 * total_papers
category_counts = category_counts[category_counts >= threshold]
category_counts['etc'] = papers_df['primary_category'].value_counts()[papers_df['primary_category'].value_counts() < threshold].sum()

# 원 그래프 그리기
plt.figure(figsize=(8, 8))
plt.pie(category_counts, labels=category_counts.index, autopct='%1.1f%%', startangle=140)
#plt.title('Primary Category Distribution as Pie Chart')
plt.savefig('AAAI_Pie Chart.pdf', format='pdf', dpi=300)  # DPI 설정으로 해상도 조정
plt.show()
plt.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 14
#       7 fontsize = plt.rcParams['font.size']
#      13 # 'category'에서 주 분야 추출
# ---> 14 papers_df['primary_category'] = papers_df['category'].apply(lambda x: x.split('.')[0])
#      16 # 각 주 분야의 개수 계산
#      17 category_counts = papers_df['primary_category'].value_counts()
#
# NameError: name 'papers_df' is not defined

# %%
df = pd.read_parquet('MathBridge_ver2', engine='fastparquet')

# %%
df.columns
# Out:
# Index(['context_before', 'equation', 'context_after', 'eq_type', 'paper_type',
#        'equation_len', 'spoken_English', 'arxiv_number', 'textbook_title'],
#       dtype='object')

# %%
df = df.drop(columns=['eq_type','paper_type','arxiv_number','textbook_title'])

# %%
df.columns
# Out:
# Index(['context_before', 'equation', 'context_after', 'equation_len',
#        'spoken_English'],
#       dtype='object')

# %%
order = ['context_before', 'equation', 'context_after', 'spoken_English', 'equation_len']
df = df[order]

# %%
df
# Out:
#                                              context_before  \
# 0         The horizontal axis represents the exponent range
# 1                                                      Here
# 2                                      The agent 's actions
# 3         are modeled by a stochastic control process wi...
# 4                                                      Here
# ...                                                     ...
# 40127014               T `` ` * Find the singular values of
# 40127015  * For what fraction of the variance do the fir...
# 40127016                                             matrix
# 40127017  Evaluating the following cell will load the vo...
# 40127018                                                 If
#
#                    equation  \
# 0         $ \in [ 3 , 7 ] $
# 1                 $ d\eta $
# 2               $ a ( t ) $
# 3            $ \sigma^2_t $
# 4               $ \deltat $
# ...                     ...
# 40127014              $ A $
# 40127015              $ A $
# 40127016              $ B $
# 40127017              $ A $
# 40127018              $ A $
#
#                                               context_after  \
# 0         . We selected those categorical colors from Co...
# 1         denotes the system noise , modeled as a Wiener...
# 2         are modeled by a stochastic control process wi...
# 3         controlled by the agent and with a mean of zer...
# 4         denotes the physical time step , and we adopte...
# ...                                                     ...
# 40127014  and use them to determine the variance in the ...
# 40127015                                  and construct the
# 40127016  whose entries are the coordinates of the demea...
# 40127017
# 40127018                             can be diagonalized as
#
#                                 spoken_English  equation_len
# 0         Belongs to the interval from 3 to 7.            17
# 1                                       d eta.             9
# 2                              a function of t            11
# 3                         sigma squared sub t.            14
# 4                                     delta t.            11
# ...                                        ...           ...
# 40127014                                     A             5
# 40127015                                     A             5
# 40127016                                     B             5
# 40127017                                     A             5
# 40127018                                     A             5
#
# [23392383 rows x 5 columns]

# %%
df.to_parquet('MathBridge_ver3.parquet', engine='pyarrow')
