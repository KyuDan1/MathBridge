# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_parquet('Hyungondata.parquet', engine='fastparquet')

# %%
df.columns
# Out:
# Index(['context_before', 'equation', 'context_after', 'eq_type',
#        'paper_number'],
#       dtype='object')

# %%
import json

file_path = r'C:\Users\wjdrb\vscode_code\MathBridge_new\data\equations_with_context_0711_easy_math.jsonl'

with open(file_path) as f:
	df_easy = pd.DataFrame(json.loads(line) for line in f)

# %%
df_easy.columns
# Out:
# Index(['context_before', 'equation', 'context_after', 'eq_type',
#        'paper_number'],
#       dtype='object')

# %%
df
# Out:
#                                              context_before  \
# 0
# 1         Figures on the top row are magnified views of ...
# 2                           and the bottom row shows region
# 3         The horizontal axis represents the exponent range
# 4         Experiment II : examples of selected exponent ...
# ...                                                     ...
# 48491678         theory capturing the chiral algebra of the
# 48491679                                         em Such 2d
# 48491680  models may be useful for the study of free fie...
# 48491681                                          \\ \hline
# 48491682  \footnotesize In comparison to the process fol...
#
#                                                    equation  \
# 0         $ https : //osf.io/4xcf5/ ? view_only=94123139...
# 1                                                     $ 1 $
# 2                                                     $ 2 $
# 3                                         $ \in [ 3 , 7 ] $
# 4                                                     $ 3 $
# ...                                                     ...
# 48491678                                  $ ( A_1 , A_2 ) $
# 48491679                                   $ \cN= ( 0,2 ) $
# 48491680                                              $ V $
# 48491681                                $ BART_ { FoCus } $
# 48491682                                $ BART_ { FoCus } $
#
#                                               context_after  eq_type  \
# 0                                                       } .        0
# 1         , marked by orange-box on the left image , and...        0
# 2         . With white background , the white cylinders ...        0
# 3         . We selected those categorical colors from Co...        0
# 4                                                         ,        0
# ...                                                     ...      ...
# 48491678                           Argyres-Douglas theory .        0
# 48491679  models may be useful for the study of free fie...        0
# 48491680                                                           0
# 48491681  & FoCus dataset employs crowdworkers to create...        0
# 48491682  , we highlight three significant enhancements ...        0
#
#           paper_number
# 0           2301.00002
# 1           2301.00002
# 2           2301.00002
# 3           2301.00002
# 4           2301.00002
# ...                ...
# 48491678    2312.17747
# 48491679    2312.17747
# 48491680    2312.17747
# 48491681    2312.17748
# 48491682    2312.17748
#
# [48491683 rows x 5 columns]

# %%
df_easy
# Out:
#                 context_before  \
# 0                      the set
# 1                   is the set
# 2                  * * The set
# 3
# 4             * * Suppose that
# ...                        ...
# 289138                     The
# 289139  gives matrices so that
# 289140                     The
# 289141
# 289142                     179
#
#                                                  equation  \
# 0       $ $ S=\ { \mathtt { dog , cat , parakeet } \ }...
# 1       $ $ \mathbb { N } =\ { 1,2,3,4,5 , \ldots\ } ....
# 2       $ $ \mathbb { W } =\ { 0,1,2,3,4,5 , \ldots\ }...
# 3                                                $ \Box $
# 4                                                   $ a $
# ...                                                   ...
# 289138                                             $ LU $
# 289139                                          $ PA=LU $
# 289140                                             $ QR $
# 289141                                            $ RGB $
# 289142                             $ YC_ { b } C_ { r } $
#
#                                             context_after  eq_type  \
# 0       is the set whose members are `` dog '' , `` ca...        1
# 1       Because this set is infinite ( there are an in...        1
# 2                    is called the set of _whole numbers_        1
# 3       # # # Ordering the whole numbers Now that we h...        0
# 4                                                     and        0
# ...                                                   ...      ...
# 289138          factorization of a matrix * P , L , U = A        0
# 289139                                                           0
# 289140                            factorization of A is A        0
# 289141                                  color model , 179        0
# 289142  color model , 179 augmented matrix , 15 back s...        0
#
#                         paper_number
# 0                   1_1WholeNumIntro
# 1                   1_1WholeNumIntro
# 2                   1_1WholeNumIntro
# 3                   1_1WholeNumIntro
# 4                   1_1WholeNumIntro
# ...                              ...
# 289138  Understanding Linear Algebra
# 289139  Understanding Linear Algebra
# 289140  Understanding Linear Algebra
# 289141  Understanding Linear Algebra
# 289142  Understanding Linear Algebra
#
# [289143 rows x 5 columns]

# %%
df['paper_type'] = 'arxiv2023'

# %%
df
# Out:
#                                              context_before  \
# 0
# 1         Figures on the top row are magnified views of ...
# 2                           and the bottom row shows region
# 3         The horizontal axis represents the exponent range
# 4         Experiment II : examples of selected exponent ...
# ...                                                     ...
# 48491678         theory capturing the chiral algebra of the
# 48491679                                         em Such 2d
# 48491680  models may be useful for the study of free fie...
# 48491681                                          \\ \hline
# 48491682  \footnotesize In comparison to the process fol...
#
#                                                    equation  \
# 0         $ https : //osf.io/4xcf5/ ? view_only=94123139...
# 1                                                     $ 1 $
# 2                                                     $ 2 $
# 3                                         $ \in [ 3 , 7 ] $
# 4                                                     $ 3 $
# ...                                                     ...
# 48491678                                  $ ( A_1 , A_2 ) $
# 48491679                                   $ \cN= ( 0,2 ) $
# 48491680                                              $ V $
# 48491681                                $ BART_ { FoCus } $
# 48491682                                $ BART_ { FoCus } $
#
#                                               context_after  eq_type  \
# 0                                                       } .        0
# 1         , marked by orange-box on the left image , and...        0
# 2         . With white background , the white cylinders ...        0
# 3         . We selected those categorical colors from Co...        0
# 4                                                         ,        0
# ...                                                     ...      ...
# 48491678                           Argyres-Douglas theory .        0
# 48491679  models may be useful for the study of free fie...        0
# 48491680                                                           0
# 48491681  & FoCus dataset employs crowdworkers to create...        0
# 48491682  , we highlight three significant enhancements ...        0
#
#           paper_number paper_type
# 0           2301.00002  arxiv2023
# 1           2301.00002  arxiv2023
# 2           2301.00002  arxiv2023
# 3           2301.00002  arxiv2023
# 4           2301.00002  arxiv2023
# ...                ...        ...
# 48491678    2312.17747  arxiv2023
# 48491679    2312.17747  arxiv2023
# 48491680    2312.17747  arxiv2023
# 48491681    2312.17748  arxiv2023
# 48491682    2312.17748  arxiv2023
#
# [48491683 rows x 6 columns]

# %%
df_easy['paper_type'] = 'textbook'

# %%
df_easy
# Out:
#                 context_before  \
# 0                      the set
# 1                   is the set
# 2                  * * The set
# 3
# 4             * * Suppose that
# ...                        ...
# 289138                     The
# 289139  gives matrices so that
# 289140                     The
# 289141
# 289142                     179
#
#                                                  equation  \
# 0       $ $ S=\ { \mathtt { dog , cat , parakeet } \ }...
# 1       $ $ \mathbb { N } =\ { 1,2,3,4,5 , \ldots\ } ....
# 2       $ $ \mathbb { W } =\ { 0,1,2,3,4,5 , \ldots\ }...
# 3                                                $ \Box $
# 4                                                   $ a $
# ...                                                   ...
# 289138                                             $ LU $
# 289139                                          $ PA=LU $
# 289140                                             $ QR $
# 289141                                            $ RGB $
# 289142                             $ YC_ { b } C_ { r } $
#
#                                             context_after  eq_type  \
# 0       is the set whose members are `` dog '' , `` ca...        1
# 1       Because this set is infinite ( there are an in...        1
# 2                    is called the set of _whole numbers_        1
# 3       # # # Ordering the whole numbers Now that we h...        0
# 4                                                     and        0
# ...                                                   ...      ...
# 289138          factorization of a matrix * P , L , U = A        0
# 289139                                                           0
# 289140                            factorization of A is A        0
# 289141                                  color model , 179        0
# 289142  color model , 179 augmented matrix , 15 back s...        0
#
#                         paper_number paper_type
# 0                   1_1WholeNumIntro   textbook
# 1                   1_1WholeNumIntro   textbook
# 2                   1_1WholeNumIntro   textbook
# 3                   1_1WholeNumIntro   textbook
# 4                   1_1WholeNumIntro   textbook
# ...                              ...        ...
# 289138  Understanding Linear Algebra   textbook
# 289139  Understanding Linear Algebra   textbook
# 289140  Understanding Linear Algebra   textbook
# 289141  Understanding Linear Algebra   textbook
# 289142  Understanding Linear Algebra   textbook
#
# [289143 rows x 6 columns]

# %%
df_combined = pd.concat([df, df_easy], ignore_index=True)

# %%
df_combined
# Out:
#                                              context_before  \
# 0
# 1         Figures on the top row are magnified views of ...
# 2                           and the bottom row shows region
# 3         The horizontal axis represents the exponent range
# 4         Experiment II : examples of selected exponent ...
# ...                                                     ...
# 48780821                                                The
# 48780822                             gives matrices so that
# 48780823                                                The
# 48780824
# 48780825                                                179
#
#                                                    equation  \
# 0         $ https : //osf.io/4xcf5/ ? view_only=94123139...
# 1                                                     $ 1 $
# 2                                                     $ 2 $
# 3                                         $ \in [ 3 , 7 ] $
# 4                                                     $ 3 $
# ...                                                     ...
# 48780821                                             $ LU $
# 48780822                                          $ PA=LU $
# 48780823                                             $ QR $
# 48780824                                            $ RGB $
# 48780825                             $ YC_ { b } C_ { r } $
#
#                                               context_after  eq_type  \
# 0                                                       } .        0
# 1         , marked by orange-box on the left image , and...        0
# 2         . With white background , the white cylinders ...        0
# 3         . We selected those categorical colors from Co...        0
# 4                                                         ,        0
# ...                                                     ...      ...
# 48780821          factorization of a matrix * P , L , U = A        0
# 48780822                                                           0
# 48780823                            factorization of A is A        0
# 48780824                                  color model , 179        0
# 48780825  color model , 179 augmented matrix , 15 back s...        0
#
#                           paper_number paper_type
# 0                           2301.00002  arxiv2023
# 1                           2301.00002  arxiv2023
# 2                           2301.00002  arxiv2023
# 3                           2301.00002  arxiv2023
# 4                           2301.00002  arxiv2023
# ...                                ...        ...
# 48780821  Understanding Linear Algebra   textbook
# 48780822  Understanding Linear Algebra   textbook
# 48780823  Understanding Linear Algebra   textbook
# 48780824  Understanding Linear Algebra   textbook
# 48780825  Understanding Linear Algebra   textbook
#
# [48780826 rows x 6 columns]

# %%
df_combined['equation_len'] = df_combined['equation'].apply(len)

# %%
df_combined['equation_len'].describe()
# Out:
# count    4.878083e+07
# mean     2.042373e+01
# std      1.797629e+01
# min      5.000000e+00
# 25%      7.000000e+00
# 50%      1.400000e+01
# 75%      2.600000e+01
# max      1.000000e+02
# Name: equation_len, dtype: float64

# %%
plt.figure(figsize=(10, 6))
plt.hist(df_combined['equation_len'], bins = 150, )
plt.xlabel('Text Length')
plt.ylabel('Frequency')
plt.show()

# %%
count = (df_combined['equation_len'] == 5).sum()
count
# Out:
# 7112204

# %% [markdown]
# ## character 하나짜리 - len = 5
# ## 7112204 개

# %%
df_len_5 = df_combined[df_combined['equation_len'] == 5]

# %%
df_not_len_5 = df_combined[df_combined['equation_len'] != 5]

# %%
df_len_5
# Out:
#                                              context_before equation  \
# 1         Figures on the top row are magnified views of ...    $ 1 $
# 2                           and the bottom row shows region    $ 2 $
# 4         Experiment II : examples of selected exponent ...    $ 3 $
# 5                                                              $ 5 $
# 6                                                       and    $ 7 $
# ...                                                     ...      ...
# 48780808               T `` ` * Find the singular values of    $ A $
# 48780809  * For what fraction of the variance do the fir...    $ A $
# 48780811                                             matrix    $ B $
# 48780814  Evaluating the following cell will load the vo...    $ A $
# 48780819                                                 If    $ A $
#
#                                               context_after  eq_type  \
# 1         , marked by orange-box on the left image , and...        0
# 2         . With white background , the white cylinders ...        0
# 4                                                         ,        0
# 5                                                     , and        0
# 6         ( from the second left to right ) . We could s...        0
# ...                                                     ...      ...
# 48780808  and use them to determine the variance in the ...        0
# 48780809                                  and construct the        0
# 48780811  whose entries are the coordinates of the demea...        0
# 48780814                                                           0
# 48780819                             can be diagonalized as        0
#
#                           paper_number paper_type  equation_len
# 1                           2301.00002  arxiv2023             5
# 2                           2301.00002  arxiv2023             5
# 4                           2301.00002  arxiv2023             5
# 5                           2301.00002  arxiv2023             5
# 6                           2301.00002  arxiv2023             5
# ...                                ...        ...           ...
# 48780808  Understanding Linear Algebra   textbook             5
# 48780809  Understanding Linear Algebra   textbook             5
# 48780811  Understanding Linear Algebra   textbook             5
# 48780814  Understanding Linear Algebra   textbook             5
# 48780819  Understanding Linear Algebra   textbook             5
#
# [7112204 rows x 7 columns]

# %%
unique_equations = df_len_5['equation'].unique()

# %%
unique_equations
# Out:
# array(['$ 1 $', '$ 2 $', '$ 3 $', '$ 5 $', '$ 7 $', '$ | $', '$ f $',
#        '$ g $', '$ t $', '$ I $', '$ a $', '$ s $', '$ F $', '$ r $',
#        '$ x $', '$ A $', '$ P $', '$ i $', '$ m $', '$ M $', '$ d $',
#        '$ z $', '$ l $', '$ y $', '$ j $', '$ k $', '$ v $', '$ w $',
#        '$ S $', '$ H $', '$ N $', '$ p $', '$ 0 $', '$ E $', '$ X $',
#        '$ U $', '$ L $', '$ u $', '$ c $', '$ C $', '$ Z $', '$ R $',
#        '$ D $', '$ h $', '$ K $', '$ T $', '$ n $', '$ + $', '$ - $',
#        '$ b $', '$ 4 $', '$ G $', '$ V $', '$ < $', '$ W $', '$ q $',
#        '$ Q $', '$ Y $', '$ J $', '$ B $', '$ , $', '$ e $', '$ 9 $',
#        '$ o $', '$ & $', '$ } $', '$ 6 $', '$ 8 $', '$ ) $', '$ ( $',
#        '$ : $', '$ — $', '$ = $', '$ / $', '$ O $', '$ { $', '$ > $',
#        '$ . $', '$ \\ $', '$ % $', "$ ' $", '$ * $', '$ ; $', '$ [ $',
#        '$ ] $', '$ ℓ $', '$ τ $', '$ ~ $', '$ @ $', '$ ! $', '$ − $',
#        '$ ? $', '$ С $', '$ # $', '$ _ $', '$ Å $', '$ 이 $', '$ ρ $',
#        '$ σ $', '$ γ $', '$ – $', '$ ` $', '$ … $', '$ · $', '$ μ $',
#        '$ β $', '$ η $', '$ ζ $', '$ à $', '$ α $', '$ ≺ $', '$ ≼ $',
#        '$ ⊕ $', '$ π $', '$ Ṛ $', '$ ⟺ $', '$ λ $', '$ δ $', '$ ⇒ $',
#        '$ ⊇ $', '$ ≥ $', '$ ≤ $', '$ µ $', '$ ε $', '$ Ω $', '$ ψ $',
#        '$ ” $', '$ ° $', '$ ∼ $', '$ × $', '$ Γ $', '$ ∈ $', '$ § $',
#        '$ θ $', '$ и $', '$ 和 $', '$ ^ $', '$ ± $', '$ ⩽ $', '$ ν $',
#        '$ φ $', '$ κ $', '$ ω $', '$ ℂ $', '$ Φ $', '$ Ψ $', '$ А $',
#        '$ ’ $', '$ ← $', '$ ℤ $', '$ と $', '$ æ $', '$ • $', '$ が $',
#        '$ Λ $', '$ ι $', '$ Π $', '$ ϕ $', '$ 、 $', '$ 从 $', '$ Ω $',
#        '$ ⇑ $', '$ → $', '$ χ $', '$ ★ $', '$ ⟨ $', '$ ⟩ $', '$ ∗ $',
#        '$ ł $', '$ ø $', '$ Х $', '$ ∇ $', '$ ξ $', '$ ϒ $', '$ ｜ $',
#        '$ ∏ $', '$ Θ $', '$ Ξ $', '$ Δ $', '$ ℚ $', '$ ， $', '$ ∑ $'],
#       dtype=object)

# %%
pronunciation_dict = {
    '$ 1 $': 'one', '$ 2 $': 'two', '$ 3 $': 'three', '$ 5 $': 'five', '$ 7 $': 'seven',
    '$ | $': 'pipe', '$ f $': 'f', '$ g $': 'g', '$ t $': 't', '$ I $': 'I', '$ a $': 'a',
    '$ s $': 's', '$ F $': 'F', '$ r $': 'r', '$ x $': 'x', '$ A $': 'A', '$ P $': 'P',
    '$ i $': 'i', '$ m $': 'm', '$ M $': 'M', '$ d $': 'd', '$ z $': 'z', '$ l $': 'l',
    '$ y $': 'y', '$ j $': 'j', '$ k $': 'k', '$ v $': 'v', '$ w $': 'w', '$ S $': 'S',
    '$ H $': 'H', '$ N $': 'N', '$ p $': 'p', '$ 0 $': 'zero', '$ E $': 'E', '$ X $': 'X',
    '$ U $': 'U', '$ L $': 'L', '$ u $': 'u', '$ c $': 'c', '$ C $': 'C', '$ Z $': 'Z',
    '$ R $': 'R', '$ D $': 'D', '$ h $': 'h', '$ K $': 'K', '$ T $': 'T', '$ n $': 'n',
    '$ + $': 'plus', '$ - $': 'minus', '$ b $': 'b', '$ 4 $': 'four', '$ G $': 'G', 
    '$ V $': 'V', '$ < $': 'less than', '$ W $': 'W', '$ q $': 'q', '$ Q $': 'Q', 
    '$ Y $': 'Y', '$ J $': 'J', '$ B $': 'B', '$ , $': 'comma', '$ e $': 'e', 
    '$ 9 $': 'nine', '$ o $': 'o', '$ & $': 'and', '$ } $': 'closing brace', 
    '$ 6 $': 'six', '$ 8 $': 'eight', '$ ) $': 'closing parenthesis', '$ ( $': 'opening parenthesis', 
    '$ : $': 'colon', '$ — $': 'dash', '$ = $': 'equals', '$ / $': 'slash', '$ O $': 'O', 
    '$ { $': 'opening brace', '$ > $': 'greater than', '$ . $': 'dot', '$ \\ $': 'backslash', 
    '$ % $': 'percent', "$ ' $": 'apostrophe', '$ * $': 'asterisk', '$ ; $': 'semicolon', 
    '$ [ $': 'opening bracket', '$ ] $': 'closing bracket', '$ ℓ $': 'ell', '$ τ $': 'tau', 
    '$ ~ $': 'tilde', '$ @ $': 'at', '$ ! $': 'exclamation mark', '$ − $': 'minus', 
    '$ ? $': 'question mark', '$ С $': 'C', '$ # $': 'hash', '$ _ $': 'underscore', 
    '$ Å $': 'A', '$ 이 $': 'yi', '$ ρ $': 'rho', '$ σ $': 'sigma', '$ γ $': 'gamma', 
    '$ – $': 'dash', '$ ` $': 'backtick', '$ … $': 'ellipsis', '$ · $': 'dot', 
    '$ μ $': 'mu', '$ β $': 'beta', '$ η $': 'eta', '$ ζ $': 'zeta', '$ à $': 'a', 
    '$ α $': 'alpha', '$ ≺ $': 'precedes', '$ ≼ $': 'precedes or equal', '$ ⊕ $': 'xor', 
    '$ π $': 'pi', '$ Ṛ $': 'R', '$ ⟺ $': 'iff', '$ λ $': 'lambda', '$ δ $': 'delta', 
    '$ ⇒ $': 'implies', '$ ⊇ $': 'superset', '$ ≥ $': 'greater than or equal', 
    '$ ≤ $': 'less than or equal', '$ µ $': 'mu', '$ ε $': 'epsilon', '$ Ω $': 'ohm', 
    '$ ψ $': 'psi', '$ ” $': 'double quote', '$ ° $': 'degree', '$ ∼ $': 'similar', 
    '$ × $': 'times', '$ Γ $': 'gamma', '$ ∈ $': 'element of', '$ § $': 'section', 
    '$ θ $': 'theta', '$ и $': 'i', '$ 和 $': 'he', '$ ^ $': 'caret', '$ ± $': 'plus-minus', 
    '$ ⩽ $': 'less than or equal', '$ ν $': 'nu', '$ φ $': 'phi', '$ κ $': 'kappa', 
    '$ ω $': 'omega', '$ ℂ $': 'complex', '$ Φ $': 'phi', '$ Ψ $': 'psi', '$ А $': 'A', 
    '$ ’ $': 'apostrophe', '$ ← $': 'left arrow', '$ ℤ $': 'integers', '$ と $': 'to', 
    '$ æ $': 'ae', '$ • $': 'bullet', '$ が $': 'ga', '$ Λ $': 'lambda', '$ ι $': 'iota', 
    '$ Π $': 'pi', '$ ϕ $': 'phi', '$ 、 $': 'comma', '$ 从 $': 'from', '$ Ω $': 'omega', 
    '$ ⇑ $': 'up arrow', '$ → $': 'right arrow', '$ χ $': 'chi', '$ ★ $': 'star', 
    '$ ⟨ $': 'left angle', '$ ⟩ $': 'right angle', '$ ∗ $': 'star', '$ ł $': 'l', 
    '$ ø $': 'o', '$ Х $': 'X', '$ ∇ $': 'nabla', '$ ξ $': 'xi', '$ ϒ $': 'upsilon', 
    '$ ｜ $': 'pipe', '$ ∏ $': 'product', '$ Θ $': 'theta', '$ Ξ $': 'xi', '$ Δ $': 'delta', 
    '$ ℚ $': 'rationals', '$ ， $': 'comma', '$ ∑ $': 'sigma'
}

# %%
# 'equation' 열의 각 값을 발음으로 변환하여 새로운 열 'Spoken_English'로 추가
df_len_5['spoken_English'] = df_len_5['equation'].map(pronunciation_dict)
# Out:
# C:\Users\wjdrb\AppData\Local\Temp\ipykernel_5492\3284886390.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_len_5['spoken_English'] = df_len_5['equation'].map(pronunciation_dict)

# %%
df_len_5['spoken_English'].head(20)
# Out:
# 1       one
# 2       two
# 4     three
# 5      five
# 6     seven
# 7     three
# 8      five
# 9     seven
# 10     pipe
# 11     pipe
# 12     pipe
# 13     pipe
# 14     pipe
# 15     pipe
# 27        f
# 30        g
# 37        t
# 55        I
# 67        a
# 70        s
# Name: spoken_English, dtype: object

# %%
df_len_5
# Out:
#                                              context_before equation  \
# 1         Figures on the top row are magnified views of ...    $ 1 $
# 2                           and the bottom row shows region    $ 2 $
# 4         Experiment II : examples of selected exponent ...    $ 3 $
# 5                                                              $ 5 $
# 6                                                       and    $ 7 $
# ...                                                     ...      ...
# 48780808               T `` ` * Find the singular values of    $ A $
# 48780809  * For what fraction of the variance do the fir...    $ A $
# 48780811                                             matrix    $ B $
# 48780814  Evaluating the following cell will load the vo...    $ A $
# 48780819                                                 If    $ A $
#
#                                               context_after  eq_type  \
# 1         , marked by orange-box on the left image , and...        0
# 2         . With white background , the white cylinders ...        0
# 4                                                         ,        0
# 5                                                     , and        0
# 6         ( from the second left to right ) . We could s...        0
# ...                                                     ...      ...
# 48780808  and use them to determine the variance in the ...        0
# 48780809                                  and construct the        0
# 48780811  whose entries are the coordinates of the demea...        0
# 48780814                                                           0
# 48780819                             can be diagonalized as        0
#
#                           paper_number paper_type  equation_len spoken_English
# 1                           2301.00002  arxiv2023             5            one
# 2                           2301.00002  arxiv2023             5            two
# 4                           2301.00002  arxiv2023             5          three
# 5                           2301.00002  arxiv2023             5           five
# 6                           2301.00002  arxiv2023             5          seven
# ...                                ...        ...           ...            ...
# 48780808  Understanding Linear Algebra   textbook             5              A
# 48780809  Understanding Linear Algebra   textbook             5              A
# 48780811  Understanding Linear Algebra   textbook             5              B
# 48780814  Understanding Linear Algebra   textbook             5              A
# 48780819  Understanding Linear Algebra   textbook             5              A
#
# [7112204 rows x 8 columns]

# %%
df_len_5['paper_number'] = df_len_5['paper_number'].astype(str)
# Out:
# C:\Users\wjdrb\AppData\Local\Temp\ipykernel_5492\1427026157.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_len_5['paper_number'] = df_len_5['paper_number'].astype(str)

# %%
df_len_5.to_parquet('df_len_5.parquet', engine='pyarrow')

# %%
df_not_len_5
# Out:
#                                              context_before  \
# 0
# 3         The horizontal axis represents the exponent range
# 16                                                       \\
# 17
# 18                                                       \\
# ...                                                     ...
# 48780821                                                The
# 48780822                             gives matrices so that
# 48780823                                                The
# 48780824
# 48780825                                                179
#
#                                                    equation  \
# 0         $ https : //osf.io/4xcf5/ ? view_only=94123139...
# 3                                         $ \in [ 3 , 7 ] $
# 16         $ \actiontimeint=\totaltimeint , \timegapint=0 $
# 17                                               $ \cdots $
# 18        $ \actiontimeint=1 , \timegapint=\totaltimeint...
# ...                                                     ...
# 48780821                                             $ LU $
# 48780822                                          $ PA=LU $
# 48780823                                             $ QR $
# 48780824                                            $ RGB $
# 48780825                             $ YC_ { b } C_ { r } $
#
#                                               context_after  eq_type  \
# 0                                                       } .        0
# 3         . We selected those categorical colors from Co...        0
# 16                                                      } ;        0
# 17                                                    } } ;        0
# 18                                                      } ;        0
# ...                                                     ...      ...
# 48780821          factorization of a matrix * P , L , U = A        0
# 48780822                                                           0
# 48780823                            factorization of A is A        0
# 48780824                                  color model , 179        0
# 48780825  color model , 179 augmented matrix , 15 back s...        0
#
#                           paper_number paper_type  equation_len
# 0                           2301.00002  arxiv2023            72
# 3                           2301.00002  arxiv2023            17
# 16                          2301.00005  arxiv2023            48
# 17                          2301.00005  arxiv2023            10
# 18                          2301.00005  arxiv2023            62
# ...                                ...        ...           ...
# 48780821  Understanding Linear Algebra   textbook             6
# 48780822  Understanding Linear Algebra   textbook             9
# 48780823  Understanding Linear Algebra   textbook             6
# 48780824  Understanding Linear Algebra   textbook             7
# 48780825  Understanding Linear Algebra   textbook            22
#
# [41668622 rows x 7 columns]

# %%
df_not_len_5['paper_number'] = df_not_len_5['paper_number'].astype(str)
# Out:
# C:\Users\wjdrb\AppData\Local\Temp\ipykernel_5492\3300320965.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_not_len_5['paper_number'] = df_not_len_5['paper_number'].astype(str)

# %%
df_not_len_5
# Out:
#                                              context_before  \
# 0
# 3         The horizontal axis represents the exponent range
# 16                                                       \\
# 17
# 18                                                       \\
# ...                                                     ...
# 48780821                                                The
# 48780822                             gives matrices so that
# 48780823                                                The
# 48780824
# 48780825                                                179
#
#                                                    equation  \
# 0         $ https : //osf.io/4xcf5/ ? view_only=94123139...
# 3                                         $ \in [ 3 , 7 ] $
# 16         $ \actiontimeint=\totaltimeint , \timegapint=0 $
# 17                                               $ \cdots $
# 18        $ \actiontimeint=1 , \timegapint=\totaltimeint...
# ...                                                     ...
# 48780821                                             $ LU $
# 48780822                                          $ PA=LU $
# 48780823                                             $ QR $
# 48780824                                            $ RGB $
# 48780825                             $ YC_ { b } C_ { r } $
#
#                                               context_after  eq_type  \
# 0                                                       } .        0
# 3         . We selected those categorical colors from Co...        0
# 16                                                      } ;        0
# 17                                                    } } ;        0
# 18                                                      } ;        0
# ...                                                     ...      ...
# 48780821          factorization of a matrix * P , L , U = A        0
# 48780822                                                           0
# 48780823                            factorization of A is A        0
# 48780824                                  color model , 179        0
# 48780825  color model , 179 augmented matrix , 15 back s...        0
#
#                           paper_number paper_type  equation_len
# 0                           2301.00002  arxiv2023            72
# 3                           2301.00002  arxiv2023            17
# 16                          2301.00005  arxiv2023            48
# 17                          2301.00005  arxiv2023            10
# 18                          2301.00005  arxiv2023            62
# ...                                ...        ...           ...
# 48780821  Understanding Linear Algebra   textbook             6
# 48780822  Understanding Linear Algebra   textbook             9
# 48780823  Understanding Linear Algebra   textbook             6
# 48780824  Understanding Linear Algebra   textbook             7
# 48780825  Understanding Linear Algebra   textbook            22
#
# [41668622 rows x 7 columns]

# %%
df_not_len_5 = df_not_len_5[~df_not_len_5['equation'].str.contains('http')]

# %%
df_not_len_5
# Out:
#                                              context_before  \
# 3         The horizontal axis represents the exponent range
# 16                                                       \\
# 17
# 18                                                       \\
# 19
# ...                                                     ...
# 48780821                                                The
# 48780822                             gives matrices so that
# 48780823                                                The
# 48780824
# 48780825                                                179
#
#                                                    equation  \
# 3                                         $ \in [ 3 , 7 ] $
# 16         $ \actiontimeint=\totaltimeint , \timegapint=0 $
# 17                                               $ \cdots $
# 18        $ \actiontimeint=1 , \timegapint=\totaltimeint...
# 19                                               $ \cdots $
# ...                                                     ...
# 48780821                                             $ LU $
# 48780822                                          $ PA=LU $
# 48780823                                             $ QR $
# 48780824                                            $ RGB $
# 48780825                             $ YC_ { b } C_ { r } $
#
#                                               context_after  eq_type  \
# 3         . We selected those categorical colors from Co...        0
# 16                                                      } ;        0
# 17                                                    } } ;        0
# 18                                                      } ;        0
# 19                                                    } } ;        0
# ...                                                     ...      ...
# 48780821          factorization of a matrix * P , L , U = A        0
# 48780822                                                           0
# 48780823                            factorization of A is A        0
# 48780824                                  color model , 179        0
# 48780825  color model , 179 augmented matrix , 15 back s...        0
#
#                           paper_number paper_type  equation_len
# 3                           2301.00002  arxiv2023            17
# 16                          2301.00005  arxiv2023            48
# 17                          2301.00005  arxiv2023            10
# 18                          2301.00005  arxiv2023            62
# 19                          2301.00005  arxiv2023            10
# ...                                ...        ...           ...
# 48780821  Understanding Linear Algebra   textbook             6
# 48780822  Understanding Linear Algebra   textbook             9
# 48780823  Understanding Linear Algebra   textbook             6
# 48780824  Understanding Linear Algebra   textbook             7
# 48780825  Understanding Linear Algebra   textbook            22
#
# [41667648 rows x 7 columns]

# %%
df_not_len_5.to_parquet('df_not_len_5.parquet', engine='pyarrow')
